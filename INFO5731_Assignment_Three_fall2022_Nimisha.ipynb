# %% [markdown]
# <a href="https://colab.research.google.com/github/unt-iialab/INFO5731_Spring2020/blob/master/Assignments/INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
import pandas as pd
data = pd.read_csv("Tweets.csv")
data.head()
# Out:
#                                                 Text
# 0  Iâ€™m optimistic about our ability to prevent ...
# 1  The Global Fund is one of the best investments...
# 2  At the end of the day, Paulâ€™s most lasting i...
# 3  His work will continue through Partners in Hea...
# 4  Paul was never happier than when he was caring...

# %%
import re

def cleantext(tweets):
    text = re.sub(r'@[A-Za-z0-9_]+', '', tweets) #removes @mentions
    text = re.sub(r'#[A-Za-z0-9_]+', '', text) #removing Hashtag symbols.
    text = re.sub(r'RT[\s]+', '', text) #removing Retweet symbol (RT).
    text = re.sub(r'https?:\/\/\S+', '', text) #remove URL's.
    text = re.sub(r"www.\S+", "", text)
    text = re.sub('[()!?]', ' ', text)
    text = re.sub('\[.*?\]',' ', text)
    text = re.sub("[^A-Za-z0-9]"," ", text)#Filtering non-alphanumeric characters
    text = re.sub('\\n', '', text)#removing the '\n' character
    text = re.sub(r'[0-9]+', '', text)#removing numbers
    
    return text

data["Text"] = data["Text"].apply(cleantext)

#Converting the text into lower case
data['Text']=data["Text"].apply(lambda x: " ".join(x.lower() for x in x.split()))

#removing stop words
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop=stopwords.words('english')
data['Text']=data['Text'].apply(lambda x:" ".join(x for x in x.split() if x not in stop))


#Lemmatization
from textblob import Word
nltk.download('wordnet')
data['Text']=data['Text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nimis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nimis\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data.head()
# Out:
#                                                 Text
# 0  optimistic ability prevent next pandemic learn...
# 1  global fund one best investment global health ...
# 2  end day paul lasting impact found patient love...
# 3  work continue partner health incredible organi...
# 4  paul never happier caring patient one clinic h...

# %%
data.to_csv("clean_Tweets.csv", index = False)

# %%
import nltk
from nltk.util import ngrams

#Create all frequncies of unigrams, bigrams, trigrams for future use in the assignment
clean_data = open('clean_Tweets.csv', "r")
unigrams = ngrams(clean_data.read().split(), 1)
unigra_freq_dist=nltk.FreqDist(unigrams)
unigra_freq_dist
# Out:
# FreqDist({('world',): 217, ('climate',): 156, ('one',): 136, ('year',): 131, ('people',): 112, ('health',): 108, ('work',): 105, ('change',): 105, ('help',): 104, ('need',): 101, ...})

# %%
#1.1 created trigram frequncies for the whole dataset
clean_data = open('clean_Tweets.csv', "r")
trigrams = ngrams(clean_data.read().split(), 3)
trigra_freq_dist=nltk.FreqDist(trigrams)
trigra_freq_dist
# Out:
# FreqDist({('avoid', 'climate', 'disaster'): 29, ('effect', 'climate', 'change'): 11, ('fight', 'climate', 'change'): 11, ('save', 'million', 'life'): 10, ('net', 'zero', 'emission'): 8, ('worst', 'effect', 'climate'): 8, ('climate', 'change', 'need'): 7, ('avoiding', 'climate', 'disaster'): 7, ('stop', 'climate', 'change'): 7, ('greenhouse', 'gas', 'emission'): 7, ...})

# %%
clean_data = open('clean_Tweets.csv', "r")
bigrams = ngrams(clean_data.read().split(), 2)
bigra_freq_dist=nltk.FreqDist(bigrams)
bigra_freq_dist
# Out:
# FreqDist({('climate', 'change'): 93, ('climate', 'disaster'): 37, ('avoid', 'climate'): 30, ('around', 'world'): 30, ('global', 'health'): 27, ('net', 'zero'): 27, ('new', 'book'): 17, ('help', 'u'): 15, ('health', 'worker'): 14, ('look', 'forward'): 14, ...})

# %%
#1.2 calculate probabilities
def probability_bigram():
    for bigram_values in bigra_freq_dist:
        #print(bigram_values)
        print(("bigram values", bigram_values,"Probability :",bigra_freq_dist[bigram_values]/unigra_freq_dist[(bigram_values[0],)]))

probability_bigram()
# Out:
# ('bigram values', ('climate', 'change'), 'Probability :', 0.5961538461538461)
# ('bigram values', ('climate', 'disaster'), 'Probability :', 0.23717948717948717)
# ('bigram values', ('avoid', 'climate'), 'Probability :', 0.9090909090909091)
# ('bigram values', ('around', 'world'), 'Probability :', 0.7692307692307693)
# ('bigram values', ('global', 'health'), 'Probability :', 0.4153846153846154)
# ('bigram values', ('net', 'zero'), 'Probability :', 0.8709677419354839)
# ('bigram values', ('new', 'book'), 'Probability :', 0.1717171717171717)
# ('bigram values', ('help', 'u'), 'Probability :', 0.14423076923076922)
# ('bigram values', ('health', 'worker'), 'Probability :', 0.12962962962962962)
# ('bigram values', ('look', 'forward'), 'Probability :', 0.4375)
# ('bigram values', ('million', 'life'), 'Probability :', 0.30952380952380953)
# ('bigram values', ('covid', 'vaccine'), 'Probability :', 0.17105263157894737)
# ('bigram values', ('every', 'day'), 'Probability :', 0.28888888888888886)
# ('bigram values', ('zero', 'emission'), 'Probability :', 0.2608695652173913)
# ('bigram values', ('work', 'together'), 'Probability :', 0.11428571428571428)
# ('bigram values', ('young', 'people'), 'Probability :', 0.48)
# ('bigram values', ('clean', 'energy'), 'Probability :', 0.46153846153846156)
# ('bigram values', ('progress', 'made'), 'Probability :', 0.14864864864864866)
# ('bigram values', ('south', 'africa'), 'Probability :', 0.8461538461538461)
# ('bigram values', ('effect', 'climate'), 'Probability :', 0.7333333333333333)
# ('bigram values', ('fight', 'climate'), 'Probability :', 0.1774193548387097)
# ('bigram values', ('prevent', 'next'), 'Probability :', 0.37037037037037035)
# ('bigram values', ('million', 'people'), 'Probability :', 0.23809523809523808)
# ('bigram values', ('one', 'favorite'), 'Probability :', 0.07352941176470588)
# ('bigram values', ('world', 'poorest'), 'Probability :', 0.04608294930875576)
# ('bigram values', ('save', 'million'), 'Probability :', 0.47619047619047616)
# ('bigram values', ('world', 'need'), 'Probability :', 0.04608294930875576)
# ('bigram values', ('great', 'see'), 'Probability :', 0.19230769230769232)
# ('bigram values', ('high', 'school'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('greenhouse', 'gas'), 'Probability :', 1.0)
# ('bigram values', ('next', 'pandemic'), 'Probability :', 0.1836734693877551)
# ('bigram values', ('covid', 'pandemic'), 'Probability :', 0.11842105263157894)
# ('bigram values', ('income', 'country'), 'Probability :', 0.6428571428571429)
# ('bigram values', ('clean', 'technology'), 'Probability :', 0.34615384615384615)
# ('bigram values', ('energy', 'catalyst'), 'Probability :', 0.15254237288135594)
# ('bigram values', ('improve', 'life'), 'Probability :', 0.391304347826087)
# ('bigram values', ('last', 'year'), 'Probability :', 0.3)
# ('bigram values', ('health', 'care'), 'Probability :', 0.08333333333333333)
# ('bigram values', ('worst', 'effect'), 'Probability :', 0.47368421052631576)
# ('bigram values', ('one', 'best'), 'Probability :', 0.058823529411764705)
# ('bigram values', ('great', 'conversation'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('change', 'need'), 'Probability :', 0.0761904761904762)
# ('bigram values', ('save', 'life'), 'Probability :', 0.38095238095238093)
# ('bigram values', ('alzheimer', 'disease'), 'Probability :', 0.25)
# ('bigram values', ('excited', 'see'), 'Probability :', 0.17391304347826086)
# ('bigram values', ('encouraging', 'see'), 'Probability :', 0.7272727272727273)
# ('bigram values', ('could', 'help'), 'Probability :', 0.21621621621621623)
# ('bigram values', ('teacher', 'year'), 'Probability :', 0.3076923076923077)
# ('bigram values', ('across', 'country'), 'Probability :', 0.42105263157894735)
# ('bigram values', ('prevent', 'worst'), 'Probability :', 0.2962962962962963)
# ('bigram values', ('next', 'year'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('industrial', 'revolution'), 'Probability :', 1.0)
# ('bigram values', ('middle', 'income'), 'Probability :', 1.0)
# ('bigram values', ('good', 'news'), 'Probability :', 0.23333333333333334)
# ('bigram values', ('many', 'people'), 'Probability :', 0.1346153846153846)
# ('bigram values', ('r', 'amp'), 'Probability :', 0.875)
# ('bigram values', ('new', 'tool'), 'Probability :', 0.0707070707070707)
# ('bigram values', ('zero', 'carbon'), 'Probability :', 0.15217391304347827)
# ('bigram values', ('avoiding', 'climate'), 'Probability :', 0.7)
# ('bigram values', ('year', 'ago'), 'Probability :', 0.05343511450381679)
# ('bigram values', ('united', 'state'), 'Probability :', 0.875)
# ('bigram values', ('stop', 'climate'), 'Probability :', 0.4375)
# ('bigram values', ('gas', 'emission'), 'Probability :', 0.7)
# ('bigram values', ('come', 'together'), 'Probability :', 0.3)
# ('bigram values', ('next', 'one'), 'Probability :', 0.12244897959183673)
# ('bigram values', ('health', 'system'), 'Probability :', 0.05555555555555555)
# ('bigram values', ('make', 'sure'), 'Probability :', 0.07407407407407407)
# ('bigram values', ('polio', 'eradication'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('poorest', 'people'), 'Probability :', 0.46153846153846156)
# ('bigram values', ('help', 'world'), 'Probability :', 0.057692307692307696)
# ('bigram values', ('u', 'closer'), 'Probability :', 0.06593406593406594)
# ('bigram values', ('reach', 'net'), 'Probability :', 0.23076923076923078)
# ('bigram values', ('polio', 'free'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('goalkeeper', 'report'), 'Probability :', 0.75)
# ('bigram values', ('well', 'deserved'), 'Probability :', 0.3157894736842105)
# ('bigram values', ('state', 'teacher'), 'Probability :', 0.375)
# ('bigram values', ('energy', 'innovation'), 'Probability :', 0.1016949152542373)
# ('bigram values', ('change', 'world'), 'Probability :', 0.05714285714285714)
# ('bigram values', ('clinical', 'trial'), 'Probability :', 1.0)
# ('bigram values', ('best', 'investment'), 'Probability :', 0.15151515151515152)
# ('bigram values', ('tb', 'malaria'), 'Probability :', 0.7142857142857143)
# ('bigram values', ('year', 'since'), 'Probability :', 0.03816793893129771)
# ('bigram values', ('pandemic', 'prevent'), 'Probability :', 0.056818181818181816)
# ('bigram values', ('progress', 'possible'), 'Probability :', 0.06756756756756757)
# ('bigram values', ('bold', 'action'), 'Probability :', 0.7142857142857143)
# ('bigram values', ('public', 'private'), 'Probability :', 0.3125)
# ('bigram values', ('private', 'sector'), 'Probability :', 0.5)
# ('bigram values', ('fight', 'covid'), 'Probability :', 0.08064516129032258)
# ('bigram values', ('foundation', 'work'), 'Probability :', 0.10204081632653061)
# ('bigram values', ('favorite', 'author'), 'Probability :', 0.2)
# ('bigram values', ('latest', 'book'), 'Probability :', 0.35714285714285715)
# ('bigram values', ('tool', 'need'), 'Probability :', 0.15625)
# ('bigram values', ('world', 'better'), 'Probability :', 0.02304147465437788)
# ('bigram values', ('need', 'get'), 'Probability :', 0.04950495049504951)
# ('bigram values', ('better', 'understand'), 'Probability :', 0.09803921568627451)
# ('bigram values', ('book', 'year'), 'Probability :', 0.06097560975609756)
# ('bigram values', ('billion', 'people'), 'Probability :', 0.29411764705882354)
# ('bigram values', ('important', 'step'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('leader', 'around'), 'Probability :', 0.11363636363636363)
# ('bigram values', ('low', 'middle'), 'Probability :', 0.4166666666666667)
# ('bigram values', ('carbon', 'emission'), 'Probability :', 0.35714285714285715)
# ('bigram values', ('make', 'optimistic'), 'Probability :', 0.06172839506172839)
# ('bigram values', ('breakthrough', 'energy'), 'Probability :', 0.20833333333333334)
# ('bigram values', ('accelerate', 'progress'), 'Probability :', 0.2631578947368421)
# ('bigram values', ('reliable', 'affordable'), 'Probability :', 0.625)
# ('bigram values', ('need', 'fight'), 'Probability :', 0.04950495049504951)
# ('bigram values', ('learned', 'lot'), 'Probability :', 0.25)
# ('bigram values', ('forward', 'working'), 'Probability :', 0.23809523809523808)
# ('bigram values', ('fight', 'poverty'), 'Probability :', 0.08064516129032258)
# ('bigram values', ('like', 'covid'), 'Probability :', 0.0641025641025641)
# ('bigram values', ('started', 'foundation'), 'Probability :', 0.5)
# ('bigram values', ('one', 'many'), 'Probability :', 0.03676470588235294)
# ('bigram values', ('looking', 'forward'), 'Probability :', 0.38461538461538464)
# ('bigram values', ('annual', 'letter'), 'Probability :', 0.45454545454545453)
# ('bigram values', ('toughest', 'challenge'), 'Probability :', 0.5555555555555556)
# ('bigram values', ('john', 'lewis'), 'Probability :', 0.625)
# ('bigram values', ('world', 'made'), 'Probability :', 0.02304147465437788)
# ('bigram values', ('big', 'fan'), 'Probability :', 0.2631578947368421)
# ('bigram values', ('change', 'excited'), 'Probability :', 0.047619047619047616)
# ('bigram values', ('incredible', 'work'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('health', 'education'), 'Probability :', 0.046296296296296294)
# ('bigram values', ('world', 'toughest'), 'Probability :', 0.02304147465437788)
# ('bigram values', ('covid', 'last'), 'Probability :', 0.05263157894736842)
# ('bigram values', ('pandemic', 'end'), 'Probability :', 0.045454545454545456)
# ('bigram values', ('wild', 'polio'), 'Probability :', 0.5714285714285714)
# ('bigram values', ('end', 'pandemic'), 'Probability :', 0.11764705882352941)
# ('bigram values', ('one', 'day'), 'Probability :', 0.029411764705882353)
# ('bigram values', ('alzheimer', 'research'), 'Probability :', 0.125)
# ('bigram values', ('science', 'fiction'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('saving', 'life'), 'Probability :', 0.4)
# ('bigram values', ('incredible', 'progress'), 'Probability :', 0.11428571428571428)
# ('bigram values', ('need', 'innovation'), 'Probability :', 0.039603960396039604)
# ('bigram values', ('rich', 'country'), 'Probability :', 0.8)
# ('bigram values', ('gate', 'foundation'), 'Probability :', 0.5)
# ('bigram values', ('low', 'income'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('vaccine', 'prevent'), 'Probability :', 0.058823529411764705)
# ('bigram values', ('solve', 'world'), 'Probability :', 0.36363636363636365)
# ('bigram values', ('book', 'read'), 'Probability :', 0.04878048780487805)
# ('bigram values', ('hero', 'like'), 'Probability :', 0.23529411764705882)
# ('bigram values', ('fight', 'polio'), 'Probability :', 0.06451612903225806)
# ('bigram values', ('get', 'net'), 'Probability :', 0.07272727272727272)
# ('bigram values', ('energy', 'storage'), 'Probability :', 0.06779661016949153)
# ('bigram values', ('new', 'variant'), 'Probability :', 0.04040404040404041)
# ('bigram values', ('read', 'lot'), 'Probability :', 0.11764705882352941)
# ('bigram values', ('great', 'book'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('five', 'book'), 'Probability :', 0.26666666666666666)
# ('bigram values', ('shape', 'future'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('move', 'u'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('lot', 'work'), 'Probability :', 0.08695652173913043)
# ('bigram values', ('progress', 'towards'), 'Probability :', 0.05405405405405406)
# ('bigram values', ('help', 'ensure'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('thank', 'partnership'), 'Probability :', 0.11764705882352941)
# ('bigram values', ('world', 'leader'), 'Probability :', 0.018433179723502304)
# ('bigram values', ('need', 'reach'), 'Probability :', 0.039603960396039604)
# ('bigram values', ('partner', 'like'), 'Probability :', 0.12121212121212122)
# ('bigram values', ('free', 'world'), 'Probability :', 0.3076923076923077)
# ('bigram values', ('people', 'think'), 'Probability :', 0.03571428571428571)
# ('bigram values', ('new', 'industrial'), 'Probability :', 0.04040404040404041)
# ('bigram values', ('important', 'work'), 'Probability :', 0.08888888888888889)
# ('bigram values', ('deserved', 'recognition'), 'Probability :', 0.5714285714285714)
# ('bigram values', ('public', 'health'), 'Probability :', 0.25)
# ('bigram values', ('business', 'leader'), 'Probability :', 0.5714285714285714)
# ('bigram values', ('diagnostics', 'accelerator'), 'Probability :', 0.5714285714285714)
# ('bigram values', ('lesson', 'learned'), 'Probability :', 0.25)
# ('bigram values', ('brilliant', 'scientist'), 'Probability :', 0.4444444444444444)
# ('bigram values', ('better', 'data'), 'Probability :', 0.0784313725490196)
# ('bigram values', ('fight', 'malaria'), 'Probability :', 0.06451612903225806)
# ('bigram values', ('work', 'global'), 'Probability :', 0.0380952380952381)
# ('bigram values', ('sierra', 'leone'), 'Probability :', 1.0)
# ('bigram values', ('washington', 'state'), 'Probability :', 0.5)
# ('bigram values', ('join', 'u'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('emission', 'avoid'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('making', 'world'), 'Probability :', 0.19047619047619047)
# ('bigram values', ('community', 'health'), 'Probability :', 0.11764705882352941)
# ('bigram values', ('author', 'new'), 'Probability :', 0.36363636363636365)
# ('bigram values', ('find', 'answer'), 'Probability :', 0.21052631578947367)
# ('bigram values', ('manufacturing', 'capacity'), 'Probability :', 0.4444444444444444)
# ('bigram values', ('one', 'step'), 'Probability :', 0.029411764705882353)
# ('bigram values', ('step', 'closer'), 'Probability :', 0.13793103448275862)
# ('bigram values', ('good', 'job'), 'Probability :', 0.13333333333333333)
# ('bigram values', ('help', 'make'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('give', 'hope'), 'Probability :', 0.19047619047619047)
# ('bigram values', ('wait', 'see'), 'Probability :', 0.2857142857142857)
# ('bigram values', ('black', 'people'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('great', 'time'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('talk', 'climate'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('safe', 'effective'), 'Probability :', 0.2857142857142857)
# ('bigram values', ('get', 'zero'), 'Probability :', 0.07272727272727272)
# ('bigram values', ('spending', 'time'), 'Probability :', 1.0)
# ('bigram values', ('infectious', 'disease'), 'Probability :', 0.5714285714285714)
# ('bigram values', ('working', 'together'), 'Probability :', 0.0851063829787234)
# ('bigram values', ('primary', 'health'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('rashida', 'jones'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('company', 'working'), 'Probability :', 0.26666666666666666)
# ('bigram values', ('making', 'progress'), 'Probability :', 0.19047619047619047)
# ('bigram values', ('progress', 'toward'), 'Probability :', 0.05405405405405406)
# ('bigram values', ('across', 'sector'), 'Probability :', 0.21052631578947367)
# ('bigram values', ('world', 'deadliest'), 'Probability :', 0.018433179723502304)
# ('bigram values', ('affordable', 'easy'), 'Probability :', 0.5714285714285714)
# ('bigram values', ('easy', 'use'), 'Probability :', 0.2857142857142857)
# ('bigram values', ('made', 'incredible'), 'Probability :', 0.09523809523809523)
# ('bigram values', ('health', 'organization'), 'Probability :', 0.037037037037037035)
# ('bigram values', ('along', 'way'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('aid', 'tb'), 'Probability :', 0.4444444444444444)
# ('bigram values', ('new', 'generation'), 'Probability :', 0.04040404040404041)
# ('bigram values', ('last', 'pandemic'), 'Probability :', 0.1)
# ('bigram values', ('disease', 'good'), 'Probability :', 0.05172413793103448)
# ('bigram values', ('world', 'come'), 'Probability :', 0.013824884792626729)
# ('bigram values', ('optimistic', 'ever'), 'Probability :', 0.06976744186046512)
# ('bigram values', ('stop', 'alzheimer'), 'Probability :', 0.1875)
# ('bigram values', ('ending', 'pandemic'), 'Probability :', 0.375)
# ('bigram values', ('climate', 'technology'), 'Probability :', 0.019230769230769232)
# ('bigram values', ('technology', 'need'), 'Probability :', 0.08333333333333333)
# ('bigram values', ('hundred', 'million'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('health', 'infrastructure'), 'Probability :', 0.027777777777777776)
# ('bigram values', ('two', 'decade'), 'Probability :', 0.13636363636363635)
# ('bigram values', ('opportunity', 'lead'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('future', 'community'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('reaching', 'net'), 'Probability :', 0.375)
# ('bigram values', ('progress', 'climate'), 'Probability :', 0.04054054054054054)
# ('bigram values', ('recap', 'conversation'), 'Probability :', 1.0)
# ('bigram values', ('together', 'prevent'), 'Probability :', 0.07317073170731707)
# ('bigram values', ('next', 'time'), 'Probability :', 0.061224489795918366)
# ('bigram values', ('time', 'country'), 'Probability :', 0.05660377358490566)
# ('bigram values', ('developing', 'country'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('social', 'medium'), 'Probability :', 0.42857142857142855)
# ('bigram values', ('better', 'one'), 'Probability :', 0.058823529411764705)
# ('bigram values', ('get', 'ready'), 'Probability :', 0.05454545454545454)
# ('bigram values', ('company', 'like'), 'Probability :', 0.2)
# ('bigram values', ('fascinating', 'book'), 'Probability :', 0.25)
# ('bigram values', ('year', 'one'), 'Probability :', 0.022900763358778626)
# ('bigram values', ('every', 'country'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('country', 'world'), 'Probability :', 0.03296703296703297)
# ('bigram values', ('end', 'covid'), 'Probability :', 0.08823529411764706)
# ('bigram values', ('help', 'save'), 'Probability :', 0.028846153846153848)
# ('bigram values', ('strong', 'commitment'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('solution', 'need'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('zero', 'economy'), 'Probability :', 0.06521739130434782)
# ('bigram values', ('made', 'possible'), 'Probability :', 0.07142857142857142)
# ('bigram values', ('job', 'explaining'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('month', 'ago'), 'Probability :', 0.2)
# ('bigram values', ('share', 'story'), 'Probability :', 0.15)
# ('bigram values', ('really', 'enjoyed'), 'Probability :', 0.13043478260869565)
# ('bigram values', ('year', 'think'), 'Probability :', 0.022900763358778626)
# ('bigram values', ('world', 'population'), 'Probability :', 0.013824884792626729)
# ('bigram values', ('help', 'accelerate'), 'Probability :', 0.028846153846153848)
# ('bigram values', ('accelerate', 'development'), 'Probability :', 0.15789473684210525)
# ('bigram values', ('global', 'collaboration'), 'Probability :', 0.046153846153846156)
# ('bigram values', ('make', 'progress'), 'Probability :', 0.037037037037037035)
# ('bigram values', ('health', 'challenge'), 'Probability :', 0.027777777777777776)
# ('bigram values', ('grand', 'challenge'), 'Probability :', 0.75)
# ('bigram values', ('first', 'step'), 'Probability :', 0.08571428571428572)
# ('bigram values', ('zero', 'future'), 'Probability :', 0.06521739130434782)
# ('bigram values', ('people', 'ever'), 'Probability :', 0.026785714285714284)
# ('bigram values', ('power', 'innovation'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('thank', 'leadership'), 'Probability :', 0.08823529411764706)
# ('bigram values', ('need', 'help'), 'Probability :', 0.0297029702970297)
# ('bigram values', ('world', 'get'), 'Probability :', 0.013824884792626729)
# ('bigram values', ('sector', 'leader'), 'Probability :', 0.2)
# ('bigram values', ('effort', 'help'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('farmer', 'adapt'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('adapt', 'climate'), 'Probability :', 0.375)
# ('bigram values', ('science', 'innovation'), 'Probability :', 0.125)
# ('bigram values', ('impact', 'climate'), 'Probability :', 0.12)
# ('bigram values', ('making', 'sure'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('road', 'ahead'), 'Probability :', 0.75)
# ('bigram values', ('front', 'line'), 'Probability :', 1.0)
# ('bigram values', ('book', 'avoid'), 'Probability :', 0.036585365853658534)
# ('bigram values', ('vaccine', 'dos'), 'Probability :', 0.04411764705882353)
# ('bigram values', ('lower', 'cost'), 'Probability :', 0.6)
# ('bigram values', ('acute', 'phase'), 'Probability :', 1.0)
# ('bigram values', ('phase', 'pandemic'), 'Probability :', 1.0)
# ('bigram values', ('life', 'saving'), 'Probability :', 0.030927835051546393)
# ('bigram values', ('world', 'make'), 'Probability :', 0.013824884792626729)
# ('bigram values', ('new', 'year'), 'Probability :', 0.030303030303030304)
# ('bigram values', ('million', 'child'), 'Probability :', 0.07142857142857142)
# ('bigram values', ('preventable', 'disease'), 'Probability :', 0.5)
# ('bigram values', ('solve', 'climate'), 'Probability :', 0.2727272727272727)
# ('bigram values', ('world', 'excited'), 'Probability :', 0.013824884792626729)
# ('bigram values', ('prepare', 'future'), 'Probability :', 0.42857142857142855)
# ('bigram values', ('world', 'child'), 'Probability :', 0.013824884792626729)
# ('bigram values', ('vaccine', 'manufacturing'), 'Probability :', 0.04411764705882353)
# ('bigram values', ('vaccine', 'need'), 'Probability :', 0.04411764705882353)
# ('bigram values', ('glad', 'see'), 'Probability :', 0.375)
# ('bigram values', ('coming', 'together'), 'Probability :', 0.375)
# ('bigram values', ('alter', 'course'), 'Probability :', 1.0)
# ('bigram values', ('bring', 'end'), 'Probability :', 0.23076923076923078)
# ('bigram values', ('disaster', 'require'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('fighting', 'disease'), 'Probability :', 0.2)
# ('bigram values', ('world', 'help'), 'Probability :', 0.013824884792626729)
# ('bigram values', ('global', 'goal'), 'Probability :', 0.046153846153846156)
# ('bigram values', ('end', 'poverty'), 'Probability :', 0.08823529411764706)
# ('bigram values', ('country', 'region'), 'Probability :', 0.03296703296703297)
# ('bigram values', ('recently', 'sat'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('deadliest', 'animal'), 'Probability :', 0.6)
# ('bigram values', ('student', 'teacher'), 'Probability :', 0.08108108108108109)
# ('bigram values', ('next', 'generation'), 'Probability :', 0.061224489795918366)
# ('bigram values', ('every', 'sector'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('around', 'globe'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('call', 'action'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('world', 'must'), 'Probability :', 0.013824884792626729)
# ('bigram values', ('vaclav', 'smil'), 'Probability :', 1.0)
# ('bigram values', ('closer', 'ever'), 'Probability :', 0.1875)
# ('bigram values', ('safe', 'sanitation'), 'Probability :', 0.21428571428571427)
# ('bigram values', ('optimistic', 'progress'), 'Probability :', 0.06976744186046512)
# ('bigram values', ('one', 'greatest'), 'Probability :', 0.022058823529411766)
# ('bigram values', ('physical', 'economy'), 'Probability :', 0.5)
# ('bigram values', ('look', 'like'), 'Probability :', 0.09375)
# ('bigram values', ('challenging', 'time'), 'Probability :', 0.75)
# ('bigram values', ('improving', 'health'), 'Probability :', 0.3)
# ('bigram values', ('leader', 'make'), 'Probability :', 0.06818181818181818)
# ('bigram values', ('health', 'inequity'), 'Probability :', 0.027777777777777776)
# ('bigram values', ('forward', 'joining'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('step', 'right'), 'Probability :', 0.10344827586206896)
# ('bigram values', ('ever', 'seen'), 'Probability :', 0.08571428571428572)
# ('bigram values', ('one', 'reason'), 'Probability :', 0.022058823529411766)
# ('bigram values', ('must', 'work'), 'Probability :', 0.17647058823529413)
# ('bigram values', ('check', 'answer'), 'Probability :', 0.21428571428571427)
# ('bigram values', ('best', 'way'), 'Probability :', 0.09090909090909091)
# ('bigram values', ('innovation', 'clean'), 'Probability :', 0.045454545454545456)
# ('bigram values', ('energy', 'technology'), 'Probability :', 0.05084745762711865)
# ('bigram values', ('want', 'understand'), 'Probability :', 0.15)
# ('bigram values', ('address', 'climate'), 'Probability :', 0.42857142857142855)
# ('bigram values', ('answering', 'question'), 'Probability :', 1.0)
# ('bigram values', ('change', 'covid'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('come', 'ask'), 'Probability :', 0.15)
# ('bigram values', ('ask', 'anything'), 'Probability :', 0.3)
# ('bigram values', ('thanks', 'hosting'), 'Probability :', 0.06382978723404255)
# ('bigram values', ('frontline', 'health'), 'Probability :', 0.5)
# ('bigram values', ('paris', 'climate'), 'Probability :', 1.0)
# ('bigram values', ('challenge', 'world'), 'Probability :', 0.08108108108108109)
# ('bigram values', ('benefit', 'everyone'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('many', 'company'), 'Probability :', 0.057692307692307696)
# ('bigram values', ('carbon', 'future'), 'Probability :', 0.21428571428571427)
# ('bigram values', ('thanks', 'inviting'), 'Probability :', 0.06382978723404255)
# ('bigram values', ('book', 'tour'), 'Probability :', 0.036585365853658534)
# ('bigram values', ('bill', 'gate'), 'Probability :', 0.5)
# ('bigram values', ('hope', 'check'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('lead', 'world'), 'Probability :', 0.25)
# ('bigram values', ('optimistic', 'world'), 'Probability :', 0.06976744186046512)
# ('bigram values', ('world', 'work'), 'Probability :', 0.013824884792626729)
# ('bigram values', ('part', 'world'), 'Probability :', 0.21428571428571427)
# ('bigram values', ('change', 'year'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('poor', 'country'), 'Probability :', 0.42857142857142855)
# ('bigram values', ('challenge', 'like'), 'Probability :', 0.08108108108108109)
# ('bigram values', ('year', 'ahead'), 'Probability :', 0.022900763358778626)
# ('bigram values', ('better', 'place'), 'Probability :', 0.058823529411764705)
# ('bigram values', ('big', 'question'), 'Probability :', 0.15789473684210525)
# ('bigram values', ('progress', 'world'), 'Probability :', 0.04054054054054054)
# ('bigram values', ('make', 'big'), 'Probability :', 0.037037037037037035)
# ('bigram values', ('every', 'dollar'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('federal', 'government'), 'Probability :', 0.75)
# ('bigram values', ('th', 'anniversary'), 'Probability :', 0.375)
# ('bigram values', ('continued', 'commitment'), 'Probability :', 0.42857142857142855)
# ('bigram values', ('finding', 'way'), 'Probability :', 0.5)
# ('bigram values', ('disease', 'like'), 'Probability :', 0.05172413793103448)
# ('bigram values', ('last', 'month'), 'Probability :', 0.1)
# ('bigram values', ('hard', 'overstate'), 'Probability :', 0.2)
# ('bigram values', ('overstate', 'important'), 'Probability :', 0.75)
# ('bigram values', ('use', 'diagnostic'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('care', 'worker'), 'Probability :', 0.25)
# ('bigram values', ('physical', 'distancing'), 'Probability :', 0.5)
# ('bigram values', ('learning', 'home'), 'Probability :', 0.1875)
# ('bigram values', ('lot', 'people'), 'Probability :', 0.06521739130434782)
# ('bigram values', ('change', 'one'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('twenty', 'year'), 'Probability :', 1.0)
# ('bigram values', ('life', 'world'), 'Probability :', 0.030927835051546393)
# ('bigram values', ('ten', 'year'), 'Probability :', 0.75)
# ('bigram values', ('every', 'child'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('sector', 'economy'), 'Probability :', 0.2)
# ('bigram values', ('new', 'idea'), 'Probability :', 0.030303030303030304)
# ('bigram values', ('lot', 'book'), 'Probability :', 0.06521739130434782)
# ('bigram values', ('paul', 'allen'), 'Probability :', 0.3)
# ('bigram values', ('people', 'world'), 'Probability :', 0.026785714285714284)
# ('bigram values', ('blood', 'test'), 'Probability :', 0.5)
# ('bigram values', ('toughest', 'problem'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('tool', 'like'), 'Probability :', 0.09375)
# ('bigram values', ('one', 'five'), 'Probability :', 0.022058823529411766)
# ('bigram values', ('changed', 'life'), 'Probability :', 0.375)
# ('bigram values', ('possible', 'without'), 'Probability :', 0.10344827586206896)
# ('bigram values', ('life', 'work'), 'Probability :', 0.030927835051546393)
# ('bigram values', ('mind', 'blowing'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('inspired', 'story'), 'Probability :', 0.10714285714285714)
# ('bigram values', ('new', 'report'), 'Probability :', 0.030303030303030304)
# ('bigram values', ('partner', 'grantee'), 'Probability :', 0.09090909090909091)
# ('bigram values', ('one', 'billion'), 'Probability :', 0.022058823529411766)
# ('bigram values', ('year', 'old'), 'Probability :', 0.022900763358778626)
# ('bigram values', ('recently', 'wrote'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('young', 'african'), 'Probability :', 0.12)
# ('bigram values', ('leonardo', 'da'), 'Probability :', 1.0)
# ('bigram values', ('da', 'vinci'), 'Probability :', 1.0)
# ('bigram values', ('moment', 'lift'), 'Probability :', 0.6)
# ('bigram values', ('advanced', 'nuclear'), 'Probability :', 1.0)
# ('bigram values', ('nuclear', 'energy'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('people', 'life'), 'Probability :', 0.026785714285714284)
# ('bigram values', ('nobel', 'peace'), 'Probability :', 1.0)
# ('bigram values', ('peace', 'prize'), 'Probability :', 0.6)
# ('bigram values', ('learned', 'much'), 'Probability :', 0.1)
# ('bigram values', ('program', 'next'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('ensure', 'covid'), 'Probability :', 0.13333333333333333)
# ('bigram values', ('people', 'alive'), 'Probability :', 0.017857142857142856)
# ('bigram values', ('alive', 'today'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('incredible', 'organization'), 'Probability :', 0.05714285714285714)
# ('bigram values', ('family', 'friend'), 'Probability :', 0.09523809523809523)
# ('bigram values', ('whose', 'life'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('inequity', 'health'), 'Probability :', 0.18181818181818182)
# ('bigram values', ('incredible', 'opportunity'), 'Probability :', 0.05714285714285714)
# ('bigram values', ('stop', 'disease'), 'Probability :', 0.125)
# ('bigram values', ('monica', 'padman'), 'Probability :', 1.0)
# ('bigram values', ('goal', 'pandemic'), 'Probability :', 0.09090909090909091)
# ('bigram values', ('last', 'two'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('set', 'u'), 'Probability :', 0.2222222222222222)
# ('bigram values', ('ever', 'one'), 'Probability :', 0.05714285714285714)
# ('bigram values', ('explain', 'science'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('pandemic', 'preventing'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('preventing', 'next'), 'Probability :', 0.25)
# ('bigram values', ('action', 'support'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('critical', 'climate'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('green', 'industrial'), 'Probability :', 0.4)
# ('bigram values', ('build', 'success'), 'Probability :', 0.09090909090909091)
# ('bigram values', ('critical', 'preventing'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('future', 'pandemic'), 'Probability :', 0.05128205128205128)
# ('bigram values', ('country', 'like'), 'Probability :', 0.02197802197802198)
# ('bigram values', ('infrastructure', 'built'), 'Probability :', 0.25)
# ('bigram values', ('excited', 'next'), 'Probability :', 0.043478260869565216)
# ('bigram values', ('every', 'person'), 'Probability :', 0.044444444444444446)
# ('bigram values', ('young', 'girl'), 'Probability :', 0.08)
# ('bigram values', ('life', 'often'), 'Probability :', 0.020618556701030927)
# ('bigram values', ('one', 'person'), 'Probability :', 0.014705882352941176)
# ('bigram values', ('life', 'story'), 'Probability :', 0.020618556701030927)
# ('bigram values', ('powerful', 'example'), 'Probability :', 0.2)
# ('bigram values', ('important', 'reminder'), 'Probability :', 0.044444444444444446)
# ('bigram values', ('way', 'eliminate'), 'Probability :', 0.03571428571428571)
# ('bigram values', ('eliminate', 'threat'), 'Probability :', 0.2222222222222222)
# ('bigram values', ('threat', 'covid'), 'Probability :', 0.5)
# ('bigram values', ('covid', 'somewhere'), 'Probability :', 0.02631578947368421)
# ('bigram values', ('somewhere', 'eliminate'), 'Probability :', 1.0)
# ('bigram values', ('eliminate', 'everywhere'), 'Probability :', 0.2222222222222222)
# ('bigram values', ('genomic', 'sequencing'), 'Probability :', 1.0)
# ('bigram values', ('tool', 'help'), 'Probability :', 0.0625)
# ('bigram values', ('scientific', 'innovation'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('path', 'forward'), 'Probability :', 0.18181818181818182)
# ('bigram values', ('one', 'thing'), 'Probability :', 0.014705882352941176)
# ('bigram values', ('conversation', 'avoid'), 'Probability :', 0.08)
# ('bigram values', ('better', 'next'), 'Probability :', 0.0392156862745098)
# ('bigram values', ('pandemic', 'omicron'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('want', 'know'), 'Probability :', 0.1)
# ('bigram values', ('sars', 'cov'), 'Probability :', 1.0)
# ('bigram values', ('better', 'tool'), 'Probability :', 0.0392156862745098)
# ('bigram values', ('also', 'need'), 'Probability :', 0.08333333333333333)
# ('bigram values', ('health', 'goal'), 'Probability :', 0.018518518518518517)
# ('bigram values', ('people', 'like'), 'Probability :', 0.017857142857142856)
# ('bigram values', ('make', 'sense'), 'Probability :', 0.024691358024691357)
# ('bigram values', ('see', 'pandemic'), 'Probability :', 0.03225806451612903)
# ('bigram values', ('think', 'world'), 'Probability :', 0.05405405405405406)
# ('bigram values', ('ready', 'next'), 'Probability :', 0.25)
# ('bigram values', ('made', 'lot'), 'Probability :', 0.047619047619047616)
# ('bigram values', ('lot', 'discussion'), 'Probability :', 0.043478260869565216)
# ('bigram values', ('wealthy', 'country'), 'Probability :', 0.5)
# ('bigram values', ('excited', 'talk'), 'Probability :', 0.043478260869565216)
# ('bigram values', ('today', 'work'), 'Probability :', 0.03389830508474576)
# ('bigram values', ('omicron', 'variant'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('africa', 'help'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('global', 'warming'), 'Probability :', 0.03076923076923077)
# ('bigram values', ('going', 'avoid'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('disaster', 'world'), 'Probability :', 0.05128205128205128)
# ('bigram values', ('need', 'pandemic'), 'Probability :', 0.019801980198019802)
# ('bigram values', ('move', 'quickly'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('le', 'month'), 'Probability :', 0.25)
# ('bigram values', ('people', 'vx'), 'Probability :', 0.017857142857142856)
# ('bigram values', ('people', 'getting'), 'Probability :', 0.017857142857142856)
# ('bigram values', ('need', 'take'), 'Probability :', 0.019801980198019802)
# ('bigram values', ('life', 'would'), 'Probability :', 0.020618556701030927)
# ('bigram values', ('return', 'normal'), 'Probability :', 0.5)
# ('bigram values', ('worker', 'community'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('new', 'app'), 'Probability :', 0.020202020202020204)
# ('bigram values', ('case', 'amp'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('prime', 'minister'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('better', 'prepared'), 'Probability :', 0.0392156862745098)
# ('bigram values', ('fight', 'neglected'), 'Probability :', 0.03225806451612903)
# ('bigram values', ('neglected', 'tropical'), 'Probability :', 1.0)
# ('bigram values', ('tropical', 'disease'), 'Probability :', 1.0)
# ('bigram values', ('president', 'biden'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('reason', 'optimistic'), 'Probability :', 0.2222222222222222)
# ('bigram values', ('way', 'new'), 'Probability :', 0.03571428571428571)
# ('bigram values', ('way', 'explore'), 'Probability :', 0.03571428571428571)
# ('bigram values', ('long', 'duration'), 'Probability :', 0.25)
# ('bigram values', ('duration', 'energy'), 'Probability :', 0.5)
# ('bigram values', ('foundation', 'net'), 'Probability :', 0.04081632653061224)
# ('bigram values', ('u', 'better'), 'Probability :', 0.02197802197802198)
# ('bigram values', ('understand', 'variant'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('variant', 'concern'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('quickly', 'identify'), 'Probability :', 0.2222222222222222)
# ('bigram values', ('identify', 'variant'), 'Probability :', 0.2222222222222222)
# ('bigram values', ('variant', 'complicating'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('complicating', 'pandemic'), 'Probability :', 1.0)
# ('bigram values', ('would', 'loved'), 'Probability :', 0.0625)
# ('bigram values', ('loved', 'kid'), 'Probability :', 0.2)
# ('bigram values', ('lot', 'great'), 'Probability :', 0.043478260869565216)
# ('bigram values', ('health', 'climate'), 'Probability :', 0.018518518518518517)
# ('bigram values', ('forward', 'seeing'), 'Probability :', 0.09523809523809523)
# ('bigram values', ('green', 'premium'), 'Probability :', 0.4)
# ('bigram values', ('need', 'make'), 'Probability :', 0.019801980198019802)
# ('bigram values', ('bipartisan', 'infrastructure'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('infrastructure', 'investment'), 'Probability :', 0.25)
# ('bigram values', ('investment', 'job'), 'Probability :', 0.058823529411764705)
# ('bigram values', ('job', 'act'), 'Probability :', 0.09523809523809523)
# ('bigram values', ('build', 'back'), 'Probability :', 0.09090909090909091)
# ('bigram values', ('back', 'better'), 'Probability :', 0.08333333333333333)
# ('bigram values', ('better', 'act'), 'Probability :', 0.0392156862745098)
# ('bigram values', ('data', 'sharing'), 'Probability :', 0.0625)
# ('bigram values', ('still', 'lot'), 'Probability :', 0.10526315789473684)
# ('bigram values', ('student', 'outcome'), 'Probability :', 0.05405405405405406)
# ('bigram values', ('make', 'data'), 'Probability :', 0.024691358024691357)
# ('bigram values', ('step', 'toward'), 'Probability :', 0.06896551724137931)
# ('bigram values', ('improve', 'global'), 'Probability :', 0.08695652173913043)
# ('bigram values', ('end', 'malaria'), 'Probability :', 0.058823529411764705)
# ('bigram values', ('malaria', 'disease'), 'Probability :', 0.04878048780487805)
# ('bigram values', ('graduate', 'student'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('access', 'vaccine'), 'Probability :', 0.13333333333333333)
# ('bigram values', ('vaccine', 'health'), 'Probability :', 0.029411764705882353)
# ('bigram values', ('commitment', 'foundation'), 'Probability :', 0.05714285714285714)
# ('bigram values', ('supply', 'need'), 'Probability :', 0.2222222222222222)
# ('bigram values', ('always', 'fun'), 'Probability :', 0.1)
# ('bigram values', ('track', 'progress'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('end', 'crisis'), 'Probability :', 0.058823529411764705)
# ('bigram values', ('getting', 'zero'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('meet', 'challenge'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('grateful', 'leadership'), 'Probability :', 0.25)
# ('bigram values', ('climate', 'action'), 'Probability :', 0.01282051282051282)
# ('bigram values', ('deploy', 'clean'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('u', 'reach'), 'Probability :', 0.02197802197802198)
# ('bigram values', ('done', 'great'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('make', 'hopeful'), 'Probability :', 0.024691358024691357)
# ('bigram values', ('leadership', 'commitment'), 'Probability :', 0.05128205128205128)
# ('bigram values', ('reducing', 'emission'), 'Probability :', 0.25)
# ('bigram values', ('excited', 'energy'), 'Probability :', 0.043478260869565216)
# ('bigram values', ('inspiring', 'see'), 'Probability :', 0.13333333333333333)
# ('bigram values', ('see', 'commitment'), 'Probability :', 0.03225806451612903)
# ('bigram values', ('today', 'world'), 'Probability :', 0.03389830508474576)
# ('bigram values', ('development', 'new'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('invest', 'innovation'), 'Probability :', 0.18181818181818182)
# ('bigram values', ('accelerate', 'clean'), 'Probability :', 0.10526315789473684)
# ('bigram values', ('partnership', 'energy'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('top', 'priority'), 'Probability :', 0.4)
# ('bigram values', ('sure', 'world'), 'Probability :', 0.18181818181818182)
# ('bigram values', ('technology', 'innovation'), 'Probability :', 0.05555555555555555)
# ('bigram values', ('earlier', 'today'), 'Probability :', 0.2)
# ('bigram values', ('find', 'way'), 'Probability :', 0.10526315789473684)
# ('bigram values', ('climate', 'conference'), 'Probability :', 0.01282051282051282)
# ('bigram values', ('commitment', 'help'), 'Probability :', 0.05714285714285714)
# ('bigram values', ('potential', 'treatment'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('treatment', 'covid'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('disaster', 'need'), 'Probability :', 0.05128205128205128)
# ('bigram values', ('college', 'university'), 'Probability :', 0.2222222222222222)
# ('bigram values', ('university', 'student'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('student', 'anywhere'), 'Probability :', 0.05405405405405406)
# ('bigram values', ('anywhere', 'world'), 'Probability :', 0.5)
# ('bigram values', ('world', 'download'), 'Probability :', 0.009216589861751152)
# ('bigram values', ('download', 'book'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('commitment', 'partner'), 'Probability :', 0.05714285714285714)
# ('bigram values', ('eradicate', 'polio'), 'Probability :', 0.4)
# ('bigram values', ('free', 'polio'), 'Probability :', 0.15384615384615385)
# ('bigram values', ('world', 'possible'), 'Probability :', 0.009216589861751152)
# ('bigram values', ('possible', 'everyone'), 'Probability :', 0.06896551724137931)
# ('bigram values', ('like', 'shumaila'), 'Probability :', 0.02564102564102564)
# ('bigram values', ('shumaila', 'rehmani'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('million', 'health'), 'Probability :', 0.047619047619047616)
# ('bigram values', ('world', 'close'), 'Probability :', 0.009216589861751152)
# ('bigram values', ('need', 'step'), 'Probability :', 0.019801980198019802)
# ('bigram values', ('equitable', 'access'), 'Probability :', 0.2857142857142857)
# ('bigram values', ('country', 'going'), 'Probability :', 0.02197802197802198)
# ('bigram values', ('end', 'acute'), 'Probability :', 0.058823529411764705)
# ('bigram values', ('available', 'everyone'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('everyone', 'need'), 'Probability :', 0.06451612903225806)
# ('bigram values', ('create', 'new'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('energy', 'economy'), 'Probability :', 0.03389830508474576)
# ('bigram values', ('thanks', 'uk'), 'Probability :', 0.0425531914893617)
# ('bigram values', ('uk', 'government'), 'Probability :', 0.4)
# ('bigram values', ('new', 'partnership'), 'Probability :', 0.020202020202020204)
# ('bigram values', ('partnership', 'uk'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('catalyst', 'accelerate'), 'Probability :', 0.13333333333333333)
# ('bigram values', ('future', 'together'), 'Probability :', 0.05128205128205128)
# ('bigram values', ('zero', 'take'), 'Probability :', 0.043478260869565216)
# ('bigram values', ('take', 'bold'), 'Probability :', 0.044444444444444446)
# ('bigram values', ('wrote', 'two'), 'Probability :', 0.18181818181818182)
# ('bigram values', ('way', 'achieve'), 'Probability :', 0.03571428571428571)
# ('bigram values', ('make', 'right'), 'Probability :', 0.024691358024691357)
# ('bigram values', ('right', 'investment'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('decision', 'make'), 'Probability :', 0.2857142857142857)
# ('bigram values', ('make', 'thing'), 'Probability :', 0.024691358024691357)
# ('bigram values', ('access', 'covid'), 'Probability :', 0.13333333333333333)
# ('bigram values', ('fifth', 'birthday'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('reminds', 'u'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('u', 'live'), 'Probability :', 0.02197802197802198)
# ('bigram values', ('congratulation', 'well'), 'Probability :', 0.10526315789473684)
# ('bigram values', ('thoughtful', 'conversation'), 'Probability :', 0.5)
# ('bigram values', ('forward', 'continuing'), 'Probability :', 0.09523809523809523)
# ('bigram values', ('together', 'avoid'), 'Probability :', 0.04878048780487805)
# ('bigram values', ('happy', 'birthday'), 'Probability :', 0.2222222222222222)
# ('bigram values', ('great', 'example'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('amazing', 'work'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('work', 'improve'), 'Probability :', 0.01904761904761905)
# ('bigram values', ('excited', 'launch'), 'Probability :', 0.043478260869565216)
# ('bigram values', ('energy', 'secretary'), 'Probability :', 0.03389830508474576)
# ('bigram values', ('new', 'data'), 'Probability :', 0.020202020202020204)
# ('bigram values', ('many', 'others'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('pandemic', 'congratulation'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('progress', 'india'), 'Probability :', 0.02702702702702703)
# ('bigram values', ('working', 'make'), 'Probability :', 0.0425531914893617)
# ('bigram values', ('receive', 'vaccine'), 'Probability :', 1.0)
# ('bigram values', ('thanks', 'show'), 'Probability :', 0.0425531914893617)
# ('bigram values', ('report', 'share'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('share', 'lesson'), 'Probability :', 0.1)
# ('bigram values', ('leadership', 'helping'), 'Probability :', 0.05128205128205128)
# ('bigram values', ('see', 'many'), 'Probability :', 0.03225806451612903)
# ('bigram values', ('could', 'take'), 'Probability :', 0.05405405405405406)
# ('bigram values', ('thing', 'need'), 'Probability :', 0.06060606060606061)
# ('bigram values', ('need', 'develop'), 'Probability :', 0.019801980198019802)
# ('bigram values', ('let', 'u'), 'Probability :', 0.4)
# ('bigram values', ('substantially', 'alter'), 'Probability :', 1.0)
# ('bigram values', ('three', 'thing'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('coming', 'month'), 'Probability :', 0.25)
# ('bigram values', ('pandemic', 'set'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('hope', 'horizon'), 'Probability :', 0.07407407407407407)
# ('bigram values', ('world', 'working'), 'Probability :', 0.009216589861751152)
# ('bigram values', ('working', 'hard'), 'Probability :', 0.0425531914893617)
# ('bigram values', ('require', 'new'), 'Probability :', 0.25)
# ('bigram values', ('partner', 'work'), 'Probability :', 0.06060606060606061)
# ('bigram values', ('build', 'clean'), 'Probability :', 0.09090909090909091)
# ('bigram values', ('year', 'new'), 'Probability :', 0.015267175572519083)
# ('bigram values', ('disease', 'need'), 'Probability :', 0.034482758620689655)
# ('bigram values', ('pandemic', 'impact'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('people', 'everywhere'), 'Probability :', 0.017857142857142856)
# ('bigram values', ('bed', 'net'), 'Probability :', 1.0)
# ('bigram values', ('disease', 'world'), 'Probability :', 0.034482758620689655)
# ('bigram values', ('progress', 'continue'), 'Probability :', 0.02702702702702703)
# ('bigram values', ('thanks', 'work'), 'Probability :', 0.0425531914893617)
# ('bigram values', ('earlier', 'year'), 'Probability :', 0.2)
# ('bigram values', ('inspired', 'u'), 'Probability :', 0.07142857142857142)
# ('bigram values', ('many', 'u'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('help', 'get'), 'Probability :', 0.019230769230769232)
# ('bigram values', ('back', 'track'), 'Probability :', 0.08333333333333333)
# ('bigram values', ('thinking', 'today'), 'Probability :', 0.2222222222222222)
# ...
# ('bigram values', ('seyram', 'traveled'), 'Probability :', 1.0)
# ('bigram values', ('traveled', 'route'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('route', 'tomato'), 'Probability :', 1.0)
# ('bigram values', ('tomato', 'take'), 'Probability :', 1.0)
# ('bigram values', ('take', 'farm'), 'Probability :', 0.022222222222222223)
# ('bigram values', ('farm', 'table'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('table', 'along'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('way', 'learned'), 'Probability :', 0.017857142857142856)
# ('bigram values', ('learned', 'food'), 'Probability :', 0.05)
# ('bigram values', ('food', 'untapped'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('untapped', 'human'), 'Probability :', 1.0)
# ('bigram values', ('human', 'potential'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('potential', 'could'), 'Probability :', 0.08333333333333333)
# ('bigram values', ('could', 'hold'), 'Probability :', 0.02702702702702703)
# ('bigram values', ('hold', 'key'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('key', 'country'), 'Probability :', 0.125)
# ('bigram values', ('country', 'success'), 'Probability :', 0.01098901098901099)
# ('bigram values', ('success', 'wait'), 'Probability :', 0.125)
# ('bigram values', ('wait', 'catch'), 'Probability :', 0.07142857142857142)
# ('bigram values', ('catch', 'tonight'), 'Probability :', 1.0)
# ('bigram values', ('tonight', 'need'), 'Probability :', 0.25)
# ('bigram values', ('breakthrough', 'contribute'), 'Probability :', 0.041666666666666664)
# ('bigram values', ('contribute', 'climate'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('change', 'fellow'), 'Probability :', 0.009523809523809525)
# ('bigram values', ('fellow', 'innovator'), 'Probability :', 0.2)
# ('bigram values', ('innovator', 'investor'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('investor', 'let'), 'Probability :', 0.5)
# ('bigram values', ('let', 'young'), 'Probability :', 0.2)
# ('bigram values', ('like', 'winner'), 'Probability :', 0.01282051282051282)
# ('bigram values', ('winner', 'dysmus'), 'Probability :', 0.25)
# ('bigram values', ('dysmus', 'kisilu'), 'Probability :', 1.0)
# ('bigram values', ('kisilu', 'leader'), 'Probability :', 1.0)
# ('bigram values', ('leader', 'tomorrow'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('tomorrow', 'leader'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('leader', 'today'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('today', 'optimistic'), 'Probability :', 0.01694915254237288)
# ('bigram values', ('optimistic', 'global'), 'Probability :', 0.023255813953488372)
# ('bigram values', ('global', 'progress'), 'Probability :', 0.015384615384615385)
# ('bigram values', ('continue', 'long'), 'Probability :', 0.04)
# ('bigram values', ('long', 'invest'), 'Probability :', 0.125)
# ('bigram values', ('invest', 'young'), 'Probability :', 0.09090909090909091)
# ('bigram values', ('people', 'thank'), 'Probability :', 0.008928571428571428)
# ('bigram values', ('thank', 'joining'), 'Probability :', 0.029411764705882353)
# ('bigram values', ('joining', 'melinda'), 'Probability :', 0.1)
# ('bigram values', ('melinda', 'inspiring'), 'Probability :', 0.029411764705882353)
# ('bigram values', ('inspiring', 'crowd'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('crowd', 'message'), 'Probability :', 1.0)
# ('bigram values', ('message', 'global'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('climate', 'education'), 'Probability :', 0.00641025641025641)
# ('bigram values', ('education', 'let'), 'Probability :', 0.0625)
# ('bigram values', ('let', 'build'), 'Probability :', 0.2)
# ('bigram values', ('build', 'future'), 'Probability :', 0.045454545454545456)
# ('bigram values', ('future', 'keep'), 'Probability :', 0.02564102564102564)
# ('bigram values', ('keep', 'action'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('action', 'live'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('live', 'session'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('session', 'tomorrow'), 'Probability :', 1.0)
# ('bigram values', ('tomorrow', 'two'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('two', 'exciting'), 'Probability :', 0.045454545454545456)
# ('bigram values', ('exciting', 'guest'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('guest', 'sierra'), 'Probability :', 0.2)
# ('bigram values', ('leone', 'president'), 'Probability :', 0.25)
# ('bigram values', ('president', 'julius'), 'Probability :', 0.05555555555555555)
# ('bigram values', ('julius', 'maada'), 'Probability :', 1.0)
# ('bigram values', ('maada', 'bio'), 'Probability :', 1.0)
# ('bigram values', ('bio', 'sierra'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('leone', 'cio'), 'Probability :', 0.25)
# ('bigram values', ('cio', 'join'), 'Probability :', 1.0)
# ('bigram values', ('live', 'report'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('report', 'eye'), 'Probability :', 0.05555555555555555)
# ('bigram values', ('eye', 'popping'), 'Probability :', 0.5)
# ('bigram values', ('popping', 'chart'), 'Probability :', 1.0)
# ('bigram values', ('chart', 'like'), 'Probability :', 0.5)
# ('bigram values', ('one', 'zimbabwe'), 'Probability :', 0.007352941176470588)
# ('bigram values', ('zimbabwe', 'female'), 'Probability :', 1.0)
# ('bigram values', ('female', 'sex'), 'Probability :', 0.2)
# ('bigram values', ('sex', 'worker'), 'Probability :', 0.5)
# ('bigram values', ('worker', 'odds'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('odds', 'hiv'), 'Probability :', 0.2)
# ('bigram values', ('hiv', 'time'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('time', 'higher'), 'Probability :', 0.018867924528301886)
# ('bigram values', ('higher', 'general'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('general', 'population'), 'Probability :', 0.5)
# ('bigram values', ('population', 'outreach'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('outreach', 'worker'), 'Probability :', 1.0)
# ('bigram values', ('worker', 'helping'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('helping', 'change'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('change', 'leader'), 'Probability :', 0.009523809523809525)
# ('bigram values', ('leader', 'born'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('born', 'well'), 'Probability :', 0.2)
# ('bigram values', ('well', 'made'), 'Probability :', 0.05263157894736842)
# ('bigram values', ('made', 'born'), 'Probability :', 0.023809523809523808)
# ('bigram values', ('born', 'africa'), 'Probability :', 0.2)
# ('bigram values', ('africa', 'always'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('always', 'recognized'), 'Probability :', 0.05)
# ('bigram values', ('recognized', 'former'), 'Probability :', 0.5)
# ('bigram values', ('former', 'malawian'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('malawian', 'president'), 'Probability :', 1.0)
# ('bigram values', ('president', 'driving'), 'Probability :', 0.05555555555555555)
# ('bigram values', ('driving', 'recognition'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('recognition', 'development'), 'Probability :', 0.2)
# ('bigram values', ('development', 'young'), 'Probability :', 0.08333333333333333)
# ('bigram values', ('young', 'female'), 'Probability :', 0.04)
# ('bigram values', ('female', 'leader'), 'Probability :', 0.2)
# ('bigram values', ('leader', 'africa'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('population', 'living'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('living', 'le'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('day', 'thing'), 'Probability :', 0.023809523809523808)
# ('bigram values', ('thing', 'changed'), 'Probability :', 0.030303030303030304)
# ('bigram values', ('changed', 'since'), 'Probability :', 0.125)
# ('bigram values', ('since', 'check'), 'Probability :', 0.07142857142857142)
# ('bigram values', ('check', 'global'), 'Probability :', 0.07142857142857142)
# ('bigram values', ('goal', 'quiz'), 'Probability :', 0.045454545454545456)
# ('bigram values', ('quiz', 'learn'), 'Probability :', 0.25)
# ('bigram values', ('learn', 'answer'), 'Probability :', 0.041666666666666664)
# ('bigram values', ('answer', 'meet'), 'Probability :', 0.07142857142857142)
# ('bigram values', ('meet', 'new'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('generation', 'young'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('african', 'making'), 'Probability :', 0.1)
# ('bigram values', ('possible', 'think'), 'Probability :', 0.034482758620689655)
# ('bigram values', ('think', 'daughter'), 'Probability :', 0.02702702702702703)
# ('bigram values', ('daughter', 'every'), 'Probability :', 0.25)
# ('bigram values', ('day', 'think'), 'Probability :', 0.023809523809523808)
# ('bigram values', ('think', 'deserves'), 'Probability :', 0.02702702702702703)
# ('bigram values', ('deserves', 'going'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('going', 'give'), 'Probability :', 0.08333333333333333)
# ('bigram values', ('give', 'every'), 'Probability :', 0.047619047619047616)
# ('bigram values', ('every', 'kid'), 'Probability :', 0.022222222222222223)
# ('bigram values', ('kid', 'inspired'), 'Probability :', 0.07142857142857142)
# ('bigram values', ('inspired', 'dedication'), 'Probability :', 0.03571428571428571)
# ('bigram values', ('student', 'craft'), 'Probability :', 0.02702702702702703)
# ('bigram values', ('craft', 'congrats'), 'Probability :', 1.0)
# ('bigram values', ('congrats', 'named'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('named', 'washington'), 'Probability :', 0.25)
# ('bigram values', ('year', 'need'), 'Probability :', 0.007633587786259542)
# ('bigram values', ('need', 'better'), 'Probability :', 0.009900990099009901)
# ('bigram values', ('better', 'way'), 'Probability :', 0.0196078431372549)
# ('bigram values', ('way', 'diagnosing'), 'Probability :', 0.017857142857142856)
# ('bigram values', ('diagnosing', 'alzheimer'), 'Probability :', 0.5)
# ('bigram values', ('alzheimer', 'brilliant'), 'Probability :', 0.03125)
# ('bigram values', ('scientist', 'advocate'), 'Probability :', 0.05555555555555555)
# ('bigram values', ('advocate', 'like'), 'Probability :', 0.1)
# ('bigram values', ('new', 'initiative'), 'Probability :', 0.010101010101010102)
# ('bigram values', ('initiative', 'called'), 'Probability :', 0.2)
# ('bigram values', ('called', 'diagnostics'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('accelerator', 'moving'), 'Probability :', 0.25)
# ('bigram values', ('closer', 'able'), 'Probability :', 0.0625)
# ('bigram values', ('able', 'slow'), 'Probability :', 0.16666666666666666)
# ('bigram values', ('slow', 'progress'), 'Probability :', 0.125)
# ('bigram values', ('progress', 'disease'), 'Probability :', 0.013513513513513514)
# ('bigram values', ('disease', 'focus'), 'Probability :', 0.017241379310344827)
# ('bigram values', ('focus', 'diagnostics'), 'Probability :', 0.2)
# ('bigram values', ('diagnostics', 'data'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('sharing', 'bold'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('bold', 'innovation'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('innovation', 'drastically'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('drastically', 'reduce'), 'Probability :', 1.0)
# ('bigram values', ('reduce', 'impact'), 'Probability :', 0.1)
# ('bigram values', ('alzheimer', 'need'), 'Probability :', 0.03125)
# ('bigram values', ('help', 'say'), 'Probability :', 0.009615384615384616)
# ('bigram values', ('say', 'big'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('big', 'thinker'), 'Probability :', 0.05263157894736842)
# ('bigram values', ('thinker', 'welcomed'), 'Probability :', 0.25)
# ('bigram values', ('welcomed', 'fight'), 'Probability :', 1.0)
# ('bigram values', ('poverty', 'inevitable'), 'Probability :', 0.041666666666666664)
# ('bigram values', ('inevitable', 'say'), 'Probability :', 0.5)
# ('bigram values', ('say', 'data'), 'Probability :', 0.1111111111111111)
# ('bigram values', ('data', 'looking'), 'Probability :', 0.03125)
# ('bigram values', ('forward', 'spending'), 'Probability :', 0.047619047619047616)
# ('bigram values', ('time', 'president'), 'Probability :', 0.018867924528301886)
# ('bigram values', ('president', 'ghanaian'), 'Probability :', 0.05555555555555555)
# ('bigram values', ('ghanaian', 'entrepreneur'), 'Probability :', 1.0)
# ('bigram values', ('entrepreneur', 'empowering'), 'Probability :', 0.25)
# ('bigram values', ('leader', 'innovator'), 'Probability :', 0.022727272727272728)
# ('bigram values', ('innovator', 'problem'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('problem', 'solver'), 'Probability :', 0.043478260869565216)
# ('bigram values', ('solver', 'keep'), 'Probability :', 1.0)
# ('bigram values', ('keep', 'melinda'), 'Probability :', 0.06666666666666667)
# ('bigram values', ('world', 'belief'), 'Probability :', 0.004608294930875576)
# ('bigram values', ('belief', 'power'), 'Probability :', 0.5)
# ('bigram values', ('innovation', 'redefine'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('redefine', 'possible'), 'Probability :', 1.0)
# ('bigram values', ('possible', 'ability'), 'Probability :', 0.034482758620689655)
# ('bigram values', ('ability', 'young'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('people', 'drive'), 'Probability :', 0.008928571428571428)
# ('bigram values', ('drive', 'economic'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('growth', 'social'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('social', 'progress'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('progress', 'congrats'), 'Probability :', 0.013513513513513514)
# ('bigram values', ('congrats', 'receiving'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('receiving', 'lemelson'), 'Probability :', 0.25)
# ('bigram values', ('lemelson', 'mit'), 'Probability :', 1.0)
# ('bigram values', ('mit', 'prize'), 'Probability :', 0.5)
# ('bigram values', ('team', 'done'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('done', 'incredible'), 'Probability :', 0.07692307692307693)
# ('bigram values', ('incredible', 'job'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('job', 'making'), 'Probability :', 0.047619047619047616)
# ('bigram values', ('making', 'foreign'), 'Probability :', 0.047619047619047616)
# ('bigram values', ('foreign', 'language'), 'Probability :', 1.0)
# ('bigram values', ('language', 'learning'), 'Probability :', 0.5)
# ('bigram values', ('learning', 'accessible'), 'Probability :', 0.0625)
# ('bigram values', ('accessible', 'everyone'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('everyone', 'year'), 'Probability :', 0.03225806451612903)
# ('bigram values', ('old', 'rwandan'), 'Probability :', 0.2)
# ('bigram values', ('rwandan', 'jeanne'), 'Probability :', 1.0)
# ('bigram values', ('jeanne', 'arc'), 'Probability :', 1.0)
# ('bigram values', ('arc', 'girubuntu'), 'Probability :', 1.0)
# ('bigram values', ('girubuntu', 'grew'), 'Probability :', 1.0)
# ('bigram values', ('grew', 'riding'), 'Probability :', 0.5)
# ('bigram values', ('riding', 'single'), 'Probability :', 1.0)
# ('bigram values', ('single', 'speed'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('speed', 'bike'), 'Probability :', 0.25)
# ('bigram values', ('bike', 'fetch'), 'Probability :', 1.0)
# ('bigram values', ('fetch', 'water'), 'Probability :', 1.0)
# ('bigram values', ('water', 'family'), 'Probability :', 0.2)
# ('bigram values', ('family', 'racing'), 'Probability :', 0.047619047619047616)
# ('bigram values', ('racing', 'around'), 'Probability :', 1.0)
# ('bigram values', ('world', 'blazing'), 'Probability :', 0.004608294930875576)
# ('bigram values', ('blazing', 'pathway'), 'Probability :', 1.0)
# ('bigram values', ('pathway', 'female'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('female', 'athlete'), 'Probability :', 0.2)

# %%
#1.3
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from textblob import TextBlob
clean_data = open('clean_Tweets.csv', "r")

_noun = lambda pos: pos[:2] == 'NN'
tokenized = nltk.word_tokenize(clean_data.read())
nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if _noun(pos)] 
#displays all the nouns in the clean data
#print(nouns)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nimis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\nimis\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#extract noun phrases
nouns
# Out:
# ['Text',
#  'ability',
#  'prevent',
#  'pandemic',
#  'innovation',
#  'fund',
#  'investment',
#  'health',
#  'program',
#  'year',
#  'tb',
#  'malaria',
#  'covid',
#  'end',
#  'day',
#  'impact',
#  'people',
#  'today',
#  'life',
#  'work',
#  'partner',
#  'health',
#  'organization',
#  'co',
#  'legacy',
#  'paul',
#  'clinic',
#  'heart',
#  'family',
#  'friend',
#  'colleague',
#  'people',
#  'life',
#  'loss',
#  'paul',
#  'hero',
#  'fortunate',
#  'call',
#  'friend',
#  'anyone',
#  'passionate',
#  'world',
#  'inequity',
#  'health',
#  'value',
#  'year',
#  'polio',
#  'pakistan',
#  'opportunity',
#  'disease',
#  'pakistan',
#  'learn',
#  'polio',
#  'program',
#  'leader',
#  'discussion',
#  'step',
#  'eliminate',
#  'polio',
#  'country',
#  'commitment',
#  'eradication',
#  'everyone',
#  'world',
#  'prevent',
#  'thanks',
#  'shepard',
#  'monica',
#  'padman',
#  'conversation',
#  'goal',
#  'progress',
#  'year',
#  'path',
#  'success',
#  'day',
#  'alzheimer',
#  'research',
#  'covid',
#  'prevent',
#  'explain',
#  'science',
#  'fiction',
#  'help',
#  'limit',
#  'institute',
#  'health',
#  'evaluation',
#  'trust',
#  'difference',
#  'climate',
#  'progress',
#  'commit',
#  'action',
#  'support',
#  'community',
#  'energy',
#  'partner',
#  'commercialization',
#  'climate',
#  'technology',
#  'spark',
#  'revolution',
#  'london',
#  'declaration',
#  'ntds',
#  'dozen',
#  'country',
#  'disease',
#  'reach',
#  'people',
#  'treatment',
#  'kigali',
#  'declaration',
#  'build',
#  'success',
#  'country',
#  'leadership',
#  'health',
#  'system',
#  'preventing',
#  'show',
#  'country',
#  'india',
#  'health',
#  'infrastructure',
#  'organization',
#  'decade',
#  'chapter',
#  'history',
#  'board',
#  'member',
#  'help',
#  'world',
#  'person',
#  'opportunity',
#  'life',
#  'kakenya',
#  'ntaiya',
#  'tradition',
#  'plan',
#  'community',
#  'society',
#  'life',
#  'educate',
#  'girl',
#  'practice',
#  'child',
#  'marriage',
#  'person',
#  'act',
#  'bravery',
#  'change',
#  'life',
#  'story',
#  'example',
#  'reminder',
#  'world',
#  'choose',
#  'life',
#  'covid',
#  'life',
#  'malaria',
#  'view',
#  'company',
#  'zero',
#  'transition',
#  'shareholder',
#  'employee',
#  'customer',
#  'community',
#  'regulator',
#  'commissioner',
#  'importance',
#  'partnership',
#  'hope',
#  'zero',
#  'climate',
#  'change',
#  'collaboration',
#  'sector',
#  'worldwide',
#  'today',
#  'discussion',
#  'accelerate',
#  'innovation',
#  'omicron',
#  'surge',
#  'reminder',
#  'way',
#  'threat',
#  'covid',
#  'investment',
#  'tool',
#  'help',
#  'fight',
#  'covid',
#  'prevent',
#  'fight',
#  'eradicate',
#  'hiv',
#  'progress',
#  'innovation',
#  'activism',
#  'action',
#  'lesson',
#  'path',
#  'forward',
#  'covid',
#  'icymi',
#  'recap',
#  'conversation',
#  'prevent',
#  'thing',
#  'thanks',
#  'time',
#  'today',
#  'world',
#  'time',
#  'insight',
#  'amp',
#  'let',
#  'goo',
#  'conversation',
#  'avoid',
#  'appreciate',
#  'work',
#  'time',
#  'variant',
#  'lot',
#  'omicron',
#  'create',
#  'lot',
#  'immunity',
#  'year',
#  'track',
#  'genetics',
#  'time',
#  'country',
#  'experience',
#  'health',
#  'system',
#  'case',
#  'people',
#  'country',
#  'rest',
#  'year',
#  'case',
#  'covid',
#  'question',
#  'everyone',
#  'data',
#  'specie',
#  'people',
#  'make',
#  'lab',
#  'outbreak',
#  'specie',
#  'question',
#  'sars',
#  'data',
#  'polio',
#  'eradication',
#  'hiv',
#  'nutrition',
#  'lot',
#  'tool',
#  'education',
#  'innovation',
#  'health',
#  'start',
#  'pandemic',
#  'progress',
#  'health',
#  'goal',
#  'setback',
#  'country',
#  'country',
#  'make',
#  'joke',
#  'storm',
#  'foundation',
#  'mission',
#  'people',
#  'fauci',
#  'lot',
#  'misinformation',
#  'chip',
#  'make',
#  'sense',
#  'authority',
#  'need',
#  'resource',
#  'surveillance',
#  'communicate',
#  'medium',
#  'information',
#  'lot',
#  'debate',
#  'problem',
#  'online',
#  'misinformation',
#  'facebook',
#  'amp',
#  'platform',
#  'vaccine',
#  'mask',
#  'day',
#  'idea',
#  'think',
#  'world',
#  'hope',
#  'sure',
#  'country',
#  'job',
#  'mobility',
#  'mask',
#  'practice',
#  'advance',
#  'country',
#  'australia',
#  'case',
#  'isolate',
#  'people',
#  'limit',
#  'death',
#  'number',
#  'country',
#  'month',
#  'lot',
#  'difference',
#  'year',
#  'th',
#  'lot',
#  'discussion',
#  'responsibility',
#  'company',
#  'pfizer',
#  'moderna',
#  'access',
#  'gen',
#  'vaccine',
#  'immunity',
#  'question',
#  'challenge',
#  'reach',
#  'supply',
#  'pricing',
#  'country',
#  'pay',
#  'lot',
#  'income',
#  'income',
#  'pay',
#  'supply',
#  'country',
#  'others',
#  'government',
#  'mrna',
#  'vaccine',
#  'demand',
#  'supply',
#  'vaccine',
#  'country',
#  'lot',
#  'problem',
#  'logistics',
#  'health',
#  'system',
#  'country',
#  'factor',
#  'vaccine',
#  'prevent',
#  'disease',
#  'death',
#  'thing',
#  'infection',
#  'duration',
#  'need',
#  'vaccine',
#  'infection',
#  'year',
#  'duration',
#  'kick',
#  'conversation',
#  'tech',
#  'breakthrough',
#  'difference',
#  'talk',
#  'today',
#  'work',
#  'university',
#  'school',
#  'answer',
#  'question',
#  'foundation',
#  'work',
#  'opportunity',
#  'talk',
#  'field',
#  'conversation',
#  'prevent',
#  'connection',
#  'brain',
#  'rise',
#  'consciousness',
#  'ability',
#  'learn',
#  'way',
#  'world',
#  'hardest',
#  'problem',
#  'fascinating',
#  'book',
#  'year',
#  'favorite',
#  'author',
#  'book',
#  'crispr',
#  'inventor',
#  'jennifer',
#  'doudna',
#  'hero',
#  'information',
#  'hope',
#  'south',
#  'africa',
#  'tool',
#  'tool',
#  'degree',
#  'need',
#  'gap',
#  'climate',
#  'disaster',
#  'world',
#  'hero',
#  'archbishop',
#  'desmond',
#  'tutu',
#  'value',
#  'optimism',
#  'everyone',
#  'laugh',
#  'energy',
#  'sense',
#  'purpose',
#  'peace',
#  'struggle',
#  'oppression',
#  'holiday',
#  'tradition',
#  'book',
#  'family',
#  'book',
#  'year',
#  'mamello',
#  'makhele',
#  'hero',
#  'lesotho',
#  'foot',
#  'donkey',
#  'health',
#  'service',
#  'woman',
#  'story',
#  'nothing',
#  'inspiring',
#  'holiday',
#  'season',
#  'covid',
#  'end',
#  'look',
#  'time',
#  'news',
#  'omicron',
#  'country',
#  'month',
#  'month',
#  'step',
#  'case',
#  'people',
#  'people',
#  'vaccine',
#  'people',
#  'street',
#  'country',
#  'mask',
#  'indoor',
#  'protection',
#  'omicron',
#  'need',
#  'delta',
#  'surge',
#  'history',
#  'country',
#  'world',
#  'life',
#  'part',
#  'omicron',
#  'mine',
#  'holiday',
#  'plan',
#  'health',
#  'worker',
#  'community',
#  'member',
#  'disease',
#  'app',
#  'afyadata',
#  'show',
#  'case',
#  'malaria',
#  'death',
#  'inves',
#  'minister',
#  'health',
#  'strategy',
#  'japan',
#  'commitment',
#  'world',
#  'people',
#  'japan',
#  'leadership',
#  'nutrition',
#  'growth',
#  'summit',
#  'world',
#  'tackle',
#  'point',
#  'pandemic',
#  'end',
#  'covid',
#  'meet',
#  'progress',
#  'fight',
#  'disease',
#  'commitment',
#  'fight',
#  'polio',
#  'eradication',
#  'disease',
#  'elimination',
#  'help',
#  'life',
#  'order',
#  'president',
#  'signal',
#  'commitment',
#  'solution',
#  'zero',
#  'avoid',
#  'climate',
#  'disaster',
#  'year',
#  'people',
#  'reason',
#  'nutrition',
#  'shift',
#  'health',
#  'productivity',
#  'prosperity',
#  'family',
#  'community',
#  'economy',
#  'tokyo',
#  'support',
#  'nutrition',
#  'fund',
#  'tool',
#  'combat',
#  'malnutrition',
#  'year',
#  'transition',
#  'work',
#  'thing',
#  'year',
#  'rts',
#  'vaccine',
#  'help',
#  'child',
#  'way',
#  'pipeline',
#  'tool',
#  'play',
#  'part',
#  'fiction',
#  'kazuo',
#  'ishiguro',
#  'klara',
#  'sun',
#  'way',
#  'explore',
#  'duration',
#  'energy',
#  'storage',
#  'innovation',
#  'co',
#  'emission',
#  'zero',
#  'economy',
#  'giiser',
#  'increase',
#  'country',
#  'capacity',
#  'evaluation',
#  'continent',
#  'help',
#  'understand',
#  'variant',
#  'concern',
#  'vaccine',
#  'south',
#  'thing',
#  'case',
#  'amp',
#  'sequencing',
#  'capability',
#  'variant',
#  'omicron',
#  'help',
#  'world',
#  'respond',
#  'trevor',
#  'bedford',
#  'job',
#  'scientist',
#  'concern',
#  'month',
#  'help',
#  'mutates',
#  'way',
#  'lot',
#  'fiction',
#  'book',
#  'kind',
#  'novel',
#  'year',
#  'lot',
#  'speculation',
#  'shakespeare',
#  'life',
#  'son',
#  'age',
#  'hamnet',
#  'share',
#  'story',
#  'grief',
#  'tore',
#  'shakespeare',
#  'family',
#  'science',
#  'fiction',
#  'book',
#  'project',
#  'hail',
#  'fun',
#  'fan',
#  'thing',
#  'weekend',
#  'read',
#  'lot',
#  'book',
#  'year',
#  'book',
#  'year',
#  'year',
#  'pc',
#  'era',
#  'release',
#  'paul',
#  'world',
#  'microprocessor',
#  'people',
#  'world',
#  'population',
#  'lack',
#  'toilet',
#  'use',
#  'sanitation',
#  'sanitation',
#  'crisis',
#  'innovation',
#  'health',
#  'climate',
#  'look',
#  'love',
#  'message',
#  'book',
#  'order',
#  'eliminate',
#  'premium',
#  'plan',
#  'infrastructure',
#  'investment',
#  'job',
#  'act',
#  'step',
#  'path',
#  'emission',
#  'job',
#  'congress',
#  'act',
#  'help',
#  'development',
#  'climate',
#  'solution',
#  'data',
#  'collaboration',
#  'move',
#  'diagnostics',
#  'treatment',
#  'cure',
#  'lie',
#  'work',
#  'conversation',
#  'heard',
#  'climate',
#  'summit',
#  'avoid',
#  'climate',
#  'disaster',
#  'data',
#  'student',
#  'outcome',
#  'leader',
#  'policymakers',
#  'value',
#  'college',
#  'tool',
#  'data',
#  'step',
#  'ed',
#  'system',
#  'world',
#  'top',
#  'health',
#  'problem',
#  'make',
#  'progress',
#  'effect',
#  'climate',
#  'change',
#  'life',
#  'minimize',
#  'effect',
#  'health',
#  'malaria',
#  'nobody',
#  'thing',
#  'end',
#  'malaria',
#  'disease',
#  'leader',
#  'world',
#  'progress',
#  'chance',
#  'meet',
#  'graduate',
#  'student',
#  'question',
#  'health',
#  'challenge',
#  'country',
#  'access',
#  'vaccine',
#  'health',
#  'innovation',
#  'commitment',
#  'foundation',
#  'help',
#  'income',
#  'country',
#  'supply',
#  'graduate',
#  'student',
#  'thanks',
#  'challenge',
#  'health',
#  'performance',
#  'chris',
#  'karp',
#  'talent',
#  'goal',
#  'step',
#  'problem',
#  'approach',
#  'key',
#  'result',
#  'track',
#  'progress',
#  'climate',
#  'covid',
#  'threat',
#  'world',
#  'face',
#  'community',
#  'innovation',
#  'agenda',
#  'crisis',
#  'respond',
#  'carbon',
#  'emission',
#  'meet',
#  'challenge',
#  'energy',
#  'part',
#  'coalition',
#  'effort',
#  'partner',
#  'technology',
#  'zero',
#  'demand',
#  'syrinx',
#  'vaccine',
#  'production',
#  'auto',
#  'syrinx',
#  'help',
#  'income',
#  'country',
#  'covid',
#  'vaccine',
#  'leadership',
#  'energy',
#  'catalyst',
#  'sector',
#  'partner',
#  'climate',
#  'action',
#  'deploy',
#  'technology',
#  'help',
#  'net',
#  'zero',
#  'emission',
#  'thing',
#  'people',
#  'conversation',
#  'power',
#  'innovation',
#  'world',
#  'work',
#  'speak',
#  'week',
#  'optimism',
#  'passion',
#  'innovation',
#  'climate',
#  'disaster',
#  'leadership',
#  'commitment',
#  'innovate',
#  'lab',
#  'drive',
#  'need',
#  'help',
#  'world',
#  'collaboration',
#  'emission',
#  'climate',
#  'goal',
#  'work',
#  'help',
#  'energy',
#  'work',
#  'thank',
#  'partnership',
#  'smallholder',
#  'agriculture',
#  'action',
#  'funding',
#  'today',
#  'energy',
#  'thank',
#  'commitment',
#  'planet',
#  'innovation',
#  'finalist',
#  'leader',
#  'today',
#  'world',
#  'action',
#  'support',
#  'development',
#  'technology',
#  'emission',
#  'help',
#  'world',
#  'adapt',
#  'climate',
#  'energy',
#  'catalyst',
#  'sector',
#  'leader',
#  'innovation',
#  'technology',
#  'effort',
#  'help',
#  'fund',
#  'solution',
#  'revolution',
#  'farmer',
#  'adapt',
#  'climate',
#  'change',
#  'battle',
#  'hunger',
#  'poverty',
#  'challenge',
#  'investment',
#  'power',
#  'innovation',
#  'thank',
#  'b',
#  'partnership',
#  'energy',
#  'catalyst',
#  'help',
#  'climate',
#  'technology',
#  'collaboration',
#  'meeting',
#  'summit',
#  'range',
#  'way',
#  'st',
#  'discus',
#  'pm',
#  'investment',
#  'science',
#  'innovation',
#  'agriculture',
#  'r',
#  'amp',
#  'foundation',
#  'climate',
#  'change',
#  'top',
#  'priority',
#  'world',
#  'technology',
#  'innovation',
#  'message',
#  'world',
#  'leader',
#  'today',
#  'week',
#  'sector',
#  'leader',
#  'world',
#  'addition',
#  'investment',
#  'emission',
#  'climate',
#  'change',
#  'help',
#  'climate',
#  'change',
#  'world',
#  'way',
#  'accelerate',
#  'development',
#  'adoption',
#  'technology',
#  'emission',
#  'year',
#  'climate',
#  'conference',
#  'innovation',
#  'center',
#  'stage',
#  'road',
#  'pass',
#  'act',
#  'infrastructure',
#  'investment',
#  'job',
#  'act',
#  'moment',
#  'see',
#  'commitment',
#  'help',
#  'treatment',
#  'covid',
#  'nation',
#  'climate',
#  'disaster',
#  'people',
#  'idea',
#  'energy',
#  'college',
#  'university',
#  'student',
#  'world',
#  'download',
#  'book',
#  'see',
#  'commitment',
#  'partner',
#  'dedication',
#  ...]

# %%
df_noun = pd.DataFrame(nouns, columns = ['noun_phrases'])
df_noun # adding the noun phrases to the data frame
# Out:
#      noun_phrases
# 0            Text
# 1         ability
# 2         prevent
# 3        pandemic
# 4      innovation
# ...           ...
# 7346        fetch
# 7347        water
# 7348       family
# 7349        world
# 7350      athlete
#
# [7351 rows x 1 columns]

# %%
#freq of nouns
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

clean_data = open('clean_Tweets.csv', "r")
f = nltk.FreqDist(nouns)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nimis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\nimis\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
f
# Out:
# FreqDist({'world': 217, 'climate': 144, 'year': 131, 'people': 112, 'health': 108, 'change': 102, 'work': 100, 'life': 97, 'country': 91, 'book': 82, ...})

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (20 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
#calculating tf
tf_result = (data['Text']).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
tf_result.columns = ['tweet_words','tf']
tf_result
# Out:
#      tweet_words    tf
# 0     optimistic  43.0
# 1        ability   7.0
# 2        prevent  27.0
# 3           next  49.0
# 4       pandemic  88.0
# ...          ...   ...
# 2998   girubuntu   1.0
# 2999         arc   1.0
# 3000      jeanne   1.0
# 3001     rwandan   1.0
# 3002     athlete   1.0
#
# [3003 rows x 2 columns]

# %%
import numpy as np
#calculate value of tf*idf
for i,j in enumerate(tf_result['tweet_words']):
    tf_result.loc[i, 'idf'] = np.log(data.shape[0]/(len(data[data['Text'].str.contains(j)])))
tf_result['tf*idf'] = tf_result['tf'] * tf_result['idf']
tf_result
# Out:
#      tweet_words    tf       idf      tf*idf
# 0     optimistic  43.0  3.170086  136.313683
# 1        ability   7.0  4.509860   31.569020
# 2        prevent  27.0  3.194183   86.242947
# 3           next  49.0  3.079114  150.876580
# 4       pandemic  88.0  2.538307  223.371054
# ...          ...   ...       ...         ...
# 2998   girubuntu   1.0  6.907755    6.907755
# 2999         arc   1.0  3.575551    3.575551
# 3000      jeanne   1.0  6.907755    6.907755
# 3001     rwandan   1.0  6.907755    6.907755
# 3002     athlete   1.0  6.907755    6.907755
#
# [3003 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.corpus import stopwords
import numpy as np
import numpy.linalg as LA

# %%
tn_set = data['Text'].values.tolist() #train set
tt_set = "The Global Fund is one of the best investments in global health. Fully funding its programs for the next 3 years is critical to ending HIV, TB, and malaria while helping ensure COVID-19 is the last pandemic."   #Query taken from one of the tweets which is called test set
tt_set = [tt_set]
stopWords = stopwords.words('english')
vzer = CountVectorizer(stop_words = stopWords)
#print(vectorizer)
transformer = TfidfTransformer()

# %%
tnVectorizerArray = vzer.fit_transform(tn_set).toarray()
ttVectorizerArray = vzer.transform(tt_set).toarray()
cx = lambda a, b : np.inner(a, b)/(LA.norm(a)*LA.norm(b))
cosine_values = []

# %%
for vector in tnVectorizerArray:
        for testV in ttVectorizerArray:
            cosine = cx(vector, testV)
            cosine_values.append(cosine)
# Out:
# C:\Users\nimis\AppData\Local\Temp\ipykernel_2152\186869217.py:3: RuntimeWarning: invalid value encountered in true_divide
#   cx = lambda a, b : np.inner(a, b)/(LA.norm(a)*LA.norm(b))

# %%
df_result = data.filter(['Text'], axis=1)
se = pd.Series(cosine_values)
df_result['Cosine_similarity'] = se.values
df_result
# Out:
#                                                   Text  Cosine_similarity
# 0    optimistic ability prevent next pandemic learn...           0.207020
# 1    global fund one best investment global health ...           0.935414
# 2    end day paul lasting impact found patient love...           0.056344
# 3    work continue partner health incredible organi...           0.069007
# 4    paul never happier caring patient one clinic h...           0.051434
# ..                                                 ...                ...
# 995            looking forward spending time president           0.000000
# 996  ghanaian entrepreneur empowering new generatio...           0.000000
# 997  keep melinda optimistic world belief power inn...           0.000000
# 998  congrats receiving lemelson mit prize team don...           0.000000
# 999  year old rwandan jeanne arc girubuntu grew rid...           0.000000
#
# [1000 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own word embedding model**

# %% [markdown]
# (20 points). Use the data you collected for assignment two to build a word embedding model:
#
# (1) Train a 300-dimension word embedding (it can be word2vec, glove, ulmfit, bert, or others).
#
# (2) Visualize the word embedding model you created.
#
# Reference: https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
#
# Reference: https://jaketae.github.io/study/word2vec/

# %%
# Write your code here


import pandas as pd
import gensim
from gensim import models
from gensim.models import Word2Vec

df = pd.read_csv("clean_Tweets.csv")

# %%
lists = []
for i in df.index:
    y = str(df["Text"][i]).split()
    lists.append(y)

# %%
model2 = Word2Vec(lists, vector_size = 300)
print(model2)
# Out:
# Word2Vec<vocab=671, vector_size=300, alpha=0.025>

# %%
words2 = list(model2.wv.key_to_index)
words2
# Out:
# ['world',
#  'climate',
#  'one',
#  'year',
#  'people',
#  'health',
#  'change',
#  'work',
#  'help',
#  'need',
#  'new',
#  'life',
#  'u',
#  'country',
#  'pandemic',
#  'book',
#  'make',
#  'like',
#  'covid',
#  'progress',
#  'vaccine',
#  'innovation',
#  'global',
#  'see',
#  'fight',
#  'today',
#  'energy',
#  'disease',
#  'way',
#  'get',
#  'time',
#  'many',
#  'great',
#  'better',
#  'foundation',
#  'next',
#  'working',
#  'thanks',
#  'excited',
#  'lot',
#  'zero',
#  'every',
#  'important',
#  'take',
#  'leader',
#  'optimistic',
#  'million',
#  'made',
#  'day',
#  'together',
#  'malaria',
#  'leadership',
#  'future',
#  'disaster',
#  'polio',
#  'around',
#  'challenge',
#  'could',
#  'think',
#  'student',
#  'emission',
#  'technology',
#  'commitment',
#  'ever',
#  'first',
#  'incredible',
#  'end',
#  'read',
#  'community',
#  'thank',
#  'investment',
#  'story',
#  'melinda',
#  'best',
#  'avoid',
#  'thing',
#  'partner',
#  'child',
#  'alzheimer',
#  'data',
#  'would',
#  'tool',
#  'look',
#  'net',
#  'everyone',
#  'even',
#  'last',
#  'critical',
#  'good',
#  'support',
#  'step',
#  'possible',
#  'question',
#  'inspired',
#  'hope',
#  'effort',
#  'amp',
#  'prevent',
#  'opportunity',
#  'worker',
#  'talk',
#  'reach',
#  'teacher',
#  'clean',
#  'action',
#  'much',
#  'right',
#  'africa',
#  'young',
#  'favorite',
#  'impact',
#  'conversation',
#  'continue',
#  'science',
#  'poverty',
#  'back',
#  'school',
#  'breakthrough',
#  'learn',
#  'also',
#  'government',
#  'improve',
#  'problem',
#  'really',
#  'two',
#  'build',
#  'india',
#  'system',
#  'goal',
#  'making',
#  'know',
#  'family',
#  'never',
#  'job',
#  'save',
#  'forward',
#  'believe',
#  'give',
#  'learned',
#  'woman',
#  'come',
#  'want',
#  'share',
#  'always',
#  'economy',
#  'congratulation',
#  'well',
#  'still',
#  'find',
#  'across',
#  'accelerate',
#  'including',
#  'big',
#  'worst',
#  'solution',
#  'report',
#  'scientist',
#  'getting',
#  'president',
#  'dr',
#  'recently',
#  'case',
#  'create',
#  'power',
#  'partnership',
#  'use',
#  'hero',
#  'billion',
#  'week',
#  'organization',
#  'idea',
#  'must',
#  'friend',
#  'helped',
#  'lesson',
#  'news',
#  'education',
#  'learning',
#  'stop',
#  'issue',
#  'closer',
#  'love',
#  'public',
#  'state',
#  'sector',
#  'high',
#  'access',
#  'inspiring',
#  'company',
#  'catalyst',
#  'month',
#  'far',
#  'plan',
#  'may',
#  'effect',
#  'keep',
#  'death',
#  'five',
#  'live',
#  'hard',
#  'reading',
#  'helping',
#  'fighting',
#  'ensure',
#  'available',
#  'decade',
#  'research',
#  'home',
#  'part',
#  'latest',
#  'check',
#  'answer',
#  'income',
#  'amazing',
#  'easy',
#  'wait',
#  'carbon',
#  'go',
#  'toward',
#  'safe',
#  'since',
#  'kid',
#  'everything',
#  'variant',
#  'remarkable',
#  'america',
#  'done',
#  'poorest',
#  'ago',
#  'program',
#  'omicron',
#  'mosquito',
#  'meet',
#  'south',
#  'sharing',
#  'bring',
#  'person',
#  'understand',
#  'treatment',
#  'role',
#  'generation',
#  'team',
#  'free',
#  'looking',
#  'researcher',
#  'start',
#  'collaboration',
#  'care',
#  'low',
#  'development',
#  'join',
#  'ahead',
#  'fascinating',
#  'black',
#  'electricity',
#  'going',
#  'lead',
#  'digital',
#  'potential',
#  'building',
#  'move',
#  'coronavirus',
#  'history',
#  'half',
#  'invest',
#  'annual',
#  'hopeful',
#  'funding',
#  'inequity',
#  'enjoyed',
#  'show',
#  'might',
#  'toilet',
#  'sure',
#  'test',
#  'crisis',
#  'solve',
#  'encouraging',
#  'without',
#  'met',
#  'author',
#  'approach',
#  'response',
#  'path',
#  'wrote',
#  'place',
#  'mean',
#  'reduce',
#  'tackle',
#  'number',
#  'seen',
#  'avoiding',
#  'put',
#  'started',
#  'virus',
#  'african',
#  'joining',
#  'needed',
#  'greenhouse',
#  'warren',
#  'loved',
#  'enough',
#  'ask',
#  'develop',
#  'area',
#  'improving',
#  'understanding',
#  'powerful',
#  'asked',
#  'saving',
#  'advocate',
#  'beat',
#  'gas',
#  'earlier',
#  'video',
#  'paul',
#  'private',
#  'project',
#  'nearly',
#  'kind',
#  'quickly',
#  'supply',
#  'difference',
#  'list',
#  'creating',
#  'eliminate',
#  'happy',
#  'hundred',
#  'manufacturing',
#  'investing',
#  'nuclear',
#  'tech',
#  'greatest',
#  'human',
#  'identify',
#  'strong',
#  'say',
#  'entire',
#  'biggest',
#  'set',
#  'aid',
#  'brilliant',
#  'explains',
#  'summit',
#  'hear',
#  'everywhere',
#  'developing',
#  'talking',
#  'thinking',
#  'another',
#  'benefit',
#  'college',
#  'call',
#  'reason',
#  'reminder',
#  'chance',
#  'toughest',
#  'act',
#  'recommend',
#  'fund',
#  'farmer',
#  'mind',
#  'hiv',
#  'insight',
#  'eradication',
#  'early',
#  'epidemic',
#  'talked',
#  'blog',
#  'risk',
#  'leading',
#  'th',
#  'john',
#  'value',
#  'patient',
#  'trial',
#  'spread',
#  'discussion',
#  'outbreak',
#  'ready',
#  'reducing',
#  'event',
#  'coming',
#  'behind',
#  'healthier',
#  'key',
#  'humanity',
#  'r',
#  'gate',
#  'towards',
#  'fun',
#  'revolution',
#  'ai',
#  'infrastructure',
#  'united',
#  'adapt',
#  'slow',
#  'long',
#  'national',
#  'reaching',
#  'sanitation',
#  'grateful',
#  'taking',
#  'importance',
#  'ending',
#  'almost',
#  'goalkeeper',
#  'series',
#  'rest',
#  'ambitious',
#  'american',
#  'whenever',
#  'success',
#  'source',
#  'supporting',
#  'washington',
#  'le',
#  'require',
#  'diagnostic',
#  'reliable',
#  'preventing',
#  'glad',
#  'changed',
#  'ability',
#  'cause',
#  'found',
#  'example',
#  'often',
#  'nutrition',
#  'close',
#  'discus',
#  'tb',
#  'industrial',
#  'bold',
#  'already',
#  'wild',
#  'soon',
#  'infectious',
#  'gap',
#  'protect',
#  'optimism',
#  'living',
#  'affordable',
#  'equitable',
#  'deliver',
#  'tomorrow',
#  'economic',
#  'whether',
#  'diagnostics',
#  'testing',
#  'population',
#  'strategy',
#  'recent',
#  'growth',
#  'prepare',
#  'extraordinary',
#  'business',
#  'podcast',
#  'four',
#  'deserved',
#  'fan',
#  'increase',
#  'birthday',
#  'decision',
#  'achieve',
#  'food',
#  'respond',
#  'agriculture',
#  'stopping',
#  'using',
#  'congrats',
#  'thought',
#  'drive',
#  'got',
#  'proud',
#  'innovative',
#  'committed',
#  'article',
#  'social',
#  'middle',
#  'worth',
#  'equal',
#  'address',
#  'urgent',
#  'poor',
#  'continued',
#  'medical',
#  'sense',
#  'inspire',
#  'developed',
#  'thrilled',
#  'information',
#  'seattle',
#  'word',
#  'planet',
#  'drug',
#  'cost',
#  'healthcare',
#  'meeting',
#  'joined',
#  'lift',
#  'preventable',
#  'hosting',
#  'effective',
#  'requires',
#  'summer',
#  'physical',
#  'classroom',
#  'bill',
#  'exciting',
#  'though',
#  'responsible',
#  'turn',
#  'matter',
#  'blood',
#  'known',
#  'frontline',
#  'fiction',
#  'real',
#  'rashida',
#  'individual',
#  'three',
#  'shared',
#  'primary',
#  'become',
#  'anything',
#  'age',
#  'scale',
#  'able',
#  'play',
#  'thousand',
#  'others',
#  'scientific',
#  'clinical',
#  'written',
#  'called',
#  'mother',
#  'faster',
#  'truly',
#  'finding',
#  'especially',
#  'true',
#  'surprised',
#  'track',
#  'watching',
#  'lucky',
#  'continent',
#  'capacity',
#  'talent',
#  'result',
#  'gene',
#  'shape',
#  'essential',
#  'face',
#  'subject',
#  'along',
#  'impressed',
#  'watch',
#  'advance',
#  'taught',
#  'someone',
#  'girl',
#  'something',
#  'microsoft',
#  'tremendous',
#  'committing',
#  'wish',
#  'injustice',
#  'moving',
#  'born',
#  'honored',
#  'female',
#  'interested',
#  'doctor',
#  'philanthropy',
#  'odds',
#  'encourage',
#  'jones',
#  'century',
#  'candidate',
#  'lewis',
#  'letter',
#  'prize',
#  'inequality',
#  'focus',
#  'guide',
#  'co',
#  'legacy',
#  'anniversary',
#  'special',
#  'guest',
#  'wrong',
#  'initiative',
#  'career',
#  'extreme',
#  'largest',
#  'colleague',
#  'model',
#  'feed',
#  'old',
#  'within',
#  'volunteer',
#  'recommendation',
#  'celebrating',
#  'fauci',
#  'taken',
#  'peace',
#  'happen',
#  'top',
#  'employee',
#  'outcome',
#  'saw',
#  'eradicate',
#  'malnutrition',
#  'point',
#  'pledge',
#  'let',
#  'bad',
#  'service',
#  'least',
#  'holiday',
#  'led',
#  'encouraged',
#  'experience',
#  'hit',
#  'hardest',
#  'expert',
#  'came',
#  'infection',
#  'went',
#  'diagnose',
#  'moved',
#  'prepared',
#  'particularly',
#  'trying',
#  'rich',
#  'resource',
#  'sustainable',
#  'lower',
#  'different',
#  'healthy',
#  'six',
#  'water',
#  'yet',
#  'cut',
#  'dementia',
#  'boost',
#  'market',
#  'deadliest',
#  'milestone',
#  'honor',
#  'study',
#  'full',
#  'hand',
#  'terrific',
#  'reality',
#  'commit',
#  'mission',
#  'serve',
#  'green',
#  'fellow',
#  'uk',
#  'worked',
#  'dos',
#  'donation',
#  'dedication',
#  'moment',
#  'lose',
#  'bringing',
#  'passion',
#  'recognition']

# %%
print(model2.wv['like'])
# Out:
# [-1.14377197e-02  9.06757712e-02 -8.16407893e-03  3.07119172e-02
#  -4.17324388e-03 -9.83171538e-02  5.63330464e-02  1.68451399e-01
#   2.82303412e-02 -4.07524891e-02  1.67396124e-02 -6.26379326e-02
#   1.07820351e-02 -3.35503966e-02 -4.14342619e-02 -4.83511873e-02
#   3.49455588e-02  1.24477241e-02  3.23806144e-02 -1.27653312e-02
#  -3.66884470e-02 -1.98699273e-02  5.50996996e-02  2.72454438e-03
#   5.49806394e-02  1.95551496e-02 -1.17664419e-01 -1.62805971e-02
#  -4.54443321e-02 -7.64506981e-02  2.49409024e-02 -4.02115881e-02
#   2.92948447e-02 -7.05851475e-03 -3.92283173e-03  4.43957932e-02
#  -5.75885782e-03 -8.71843770e-02 -2.69489270e-02  1.43754706e-02
#  -5.59408925e-02 -5.38950460e-03 -7.54759554e-03 -4.31712270e-02
#   4.21774164e-02  8.01972374e-02  5.03567718e-02  1.00186681e-02
#  -1.79450326e-02  6.47467226e-02  2.00472716e-02  3.24013010e-02
#  -4.11693528e-02  2.73837019e-02 -5.15221581e-02  1.05764821e-01
#   3.94883603e-02 -1.02576502e-02  1.36539303e-02 -1.51398052e-02
#  -2.64360923e-02 -4.92459051e-02 -1.49895651e-02  3.74028943e-02
#   4.30377154e-03  3.97155620e-02 -3.37847136e-02  8.81336536e-03
#  -5.09397797e-02 -3.62674594e-02  3.97842145e-03  2.10897010e-02
#   8.66532400e-02 -6.97395131e-02 -1.32981583e-03  3.78441736e-02
#  -6.66800886e-02  2.27404311e-02 -3.30731049e-02  7.41510019e-02
#  -5.37892766e-02 -7.89288506e-02  1.46245793e-03  1.34906426e-01
#  -1.19966827e-02  1.72588392e-03 -6.94837347e-02  9.13646509e-05
#   8.37968066e-02  2.28820257e-02  8.01238045e-02 -5.06833531e-02
#   3.26880589e-02 -4.57624346e-03  5.64308129e-02  8.38442519e-02
#   7.31509849e-02 -3.75708416e-02 -2.32304763e-02  3.58418226e-02
#  -1.64802447e-02 -2.80236863e-02  4.26250808e-02  9.19469167e-03
#   6.19713636e-03 -5.50513715e-02 -2.29832288e-02  2.80678482e-03
#  -6.32290840e-02  5.23285046e-02 -1.07505441e-01 -2.01311588e-04
#  -5.37591521e-03  5.47545068e-02  1.73333045e-02  2.34848689e-02
#  -6.26659952e-03  2.06832984e-03  9.79597196e-02 -6.63713813e-02
#   5.71208671e-02  6.08897172e-02  5.04625998e-02 -7.00817676e-03
#  -7.31043294e-02  2.42690630e-02  2.97907386e-02 -8.30702558e-02
#   7.29055610e-03  3.41331773e-02  4.76367772e-02  8.80581290e-02
#  -1.44477719e-02 -4.56809402e-02  4.76230793e-02  1.57155488e-02
#  -4.32284810e-02 -3.89284752e-02 -7.59634823e-02 -1.08609989e-01
#   2.33751275e-02 -8.10912624e-02  2.91338153e-02  7.46460110e-02
#   1.67101100e-02 -5.27413525e-02 -9.96952653e-02 -2.04655062e-02
#   2.54004076e-02 -5.79564273e-02  5.05248876e-03 -1.34432465e-01
#  -6.40004203e-02 -2.79348381e-02  2.07684524e-02  3.03946324e-02
#  -5.02467416e-02 -5.51018231e-02 -1.34816803e-02  9.54776406e-02
#   1.74072273e-02  5.04947864e-02 -1.07926451e-01  7.85917118e-02
#  -7.37288147e-02  4.06446606e-02  2.04112977e-02  3.37852142e-03
#  -2.62804882e-04  1.19336024e-01 -5.53994589e-02 -5.76510886e-03
#   4.03437801e-02  3.82517204e-02  1.29251014e-02 -2.39474932e-03
#   1.44420261e-03 -7.61139020e-02  5.68293547e-03 -6.10224623e-03
#  -3.79845239e-02  6.44441992e-02 -4.86418530e-02 -5.57519309e-02
#   5.59554494e-04  1.68148130e-02  7.22251981e-02  9.12295580e-02
#   1.73853077e-02 -4.50049564e-02  9.75893810e-03 -2.34185308e-02
#  -6.40001446e-02  1.00888694e-02  2.62943972e-02 -5.52896559e-02
#   2.98633846e-03 -7.34930634e-02  4.09654938e-02 -4.41466505e-03
#  -1.07696421e-01  2.05775350e-02 -1.48722660e-02 -2.96632648e-02
#  -2.31039543e-02 -3.42781059e-02 -9.32358578e-03  3.40128951e-02
#  -1.43718617e-02 -1.92069504e-02  2.32277531e-03 -6.57644644e-02
#  -4.86165062e-02 -3.75291370e-02  1.36373723e-02 -9.35058817e-02
#  -3.17688249e-02 -1.24208368e-01 -1.07196152e-01 -6.71393126e-02
#   7.25388452e-02  1.52427219e-02 -5.56877218e-02 -2.98608020e-02
#  -4.54781763e-02 -5.32475561e-02 -4.46107909e-02 -2.12550443e-02
#  -6.66508451e-02  6.18451089e-02  4.75879610e-02  8.15163273e-03
#  -5.29910065e-02  5.30893169e-02 -5.77929476e-03  5.40090688e-02
#  -1.50965229e-02  1.33574754e-02  2.05656216e-02 -1.54648885e-01
#   2.69536674e-02 -1.85852870e-02 -3.84302139e-02  4.95298207e-03
#  -1.21759558e-02 -6.80640116e-02 -2.30548531e-03  3.85575667e-02
#  -2.35269777e-03  8.04980919e-02  2.43039746e-02  2.54900604e-02
#   1.56659372e-02  3.09104156e-02 -1.04892768e-01 -5.22369370e-02
#   1.27821192e-01  2.66912114e-02 -1.17893912e-01 -4.84928489e-02
#   3.40349041e-02  5.39430603e-02 -2.34859418e-02 -1.10603444e-01
#  -8.79783407e-02 -3.12996656e-02  1.52721079e-02  2.49621253e-02
#  -6.90695420e-02  1.23373065e-02 -3.78436819e-02  3.53958970e-03
#  -6.43575145e-03 -4.60545607e-02  7.54800290e-02  2.49554608e-02
#   6.99755549e-02  1.20151006e-02 -6.48675710e-02 -1.13839041e-02
#   6.83956593e-02  2.28603091e-03 -1.96592398e-02  3.04026995e-02
#   2.36811023e-02 -1.16451457e-02 -1.07607357e-01  5.70090711e-02
#  -2.52931961e-03  7.17047229e-02 -2.67652459e-02  1.13604151e-01
#   5.38522564e-02  1.42196324e-02  5.84418289e-02  1.07986785e-01
#  -2.49844287e-02 -2.31245626e-02  6.00419454e-02 -5.58916442e-02]

# %%
#3.2
from sklearn.decomposition import PCA
K = model2[model2.wv.key_to_index]
pca = PCA(n_components=2)
result = pca.fit_transform(K)

# %%
import matplotlib.pyplot as plt
plt.figure (figsize = (20,10))
plt.scatter(result[:, 0], result[:, 1])
words = list(model2.wv.vocab)
for i, word in enumerate(words):
	plt.annotate(word, xy=(result[i, 0], result[i, 1]))
plt.show()

# %% [markdown]
# # **Question 4: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file



# Link: 
print ("The final CSV file is :https://github.com/NimishaBhargavi10/ASSIGMENT/blob/main/Tweets.csv ")
# Out:
# The final CSV file is :https://github.com/NimishaBhargavi10/ASSIGMENT/blob/main/Tweets.csv
